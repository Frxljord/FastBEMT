# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
import pandas as pd
from JobParameters import AerodynamicParameters, AcousticParameters
from Propeller import Propeller
import aerosandbox as asb

with open("../10x7E.pkl", "rb") as f:
    blade_dict = pickle.load(f)

aerodynamic_params = AerodynamicParameters(
    prop_radius=blade_dict['tip_radius'],
    hub_radius=blade_dict['hub_radius'],
    n_blades=blade_dict['n_blades'],
    rpm=7000,
    a_inf=343,
    rho=1.225,
    mu=1.81e-5,
)

acoustic_params = AcousticParameters(
    aero_params=aerodynamic_params,
    p_ref=2e-5, revolutions=50, num_obs_times_per_rev=300
)

section_airfoils = [asb.Airfoil(coordinates=af) for af in blade_dict['airfoil']]

# %%
propeller = Propeller(
    propeller_geometry=blade_dict,
    aero_params=aerodynamic_params,
    acoustic_params=acoustic_params
)
v_inf = 0
propeller.run_bemt(v_inf=v_inf)

# %%
def prandtlLoss(phi, r):
    B = aerodynamic_params.n_blades

    f_tip = B * (aerodynamic_params.prop_radius - r) / (2 * r * np.sin(phi))
    f_hub = B * (r - aerodynamic_params.hub_radius) / (2 * r * np.sin(phi))

    # Clip to avoid overflow
    f_tip = np.clip(f_tip, 0.0, 500.0)
    f_hub = np.clip(f_hub, 0.0, 500.0)

    F_tip = 2 * np.arccos(np.exp(-f_tip)) / np.pi
    F_hub = 2 * np.arccos(np.exp(-f_hub)) / np.pi

    return F_tip * F_hub

# %%
from TurbulenceGenerator import TurbulenceGenerator

Ly, Lz = 0.3, 0.3     
Lx = 2 * propeller.solution_data.u.values.mean() * propeller.acoustic_params.revolutions * 60 / propeller.aero_params.rpm             

ny, nz = 100, 100
nx = int(100 * Lx)

sigma = 1  # Turbulence intensity (m/s)         
# L_scale: Set to 1/2 of diameter to see spatial variation across blades
L_scale = propeller.aero_params.prop_radius / 2       

turbulence_generator = TurbulenceGenerator(
    Lx=Lx,
    Ly=Ly,
    Lz=Lz,
    nx=nx,
    ny=ny,
    nz=nz,
    sigma=sigma,
    L_scale=L_scale,
    device='cuda'
)

u_box = turbulence_generator.generate_turbulence()

nx, ny, nz = u_box.shape

# %%
import numpy as np
from scipy.interpolate import RegularGridInterpolator

aero_caches = [{} for _ in range(len(blade_dict['r']))]

def get_cache_key(alpha, Re, Ma):
    return (round(alpha, 3), round(Re, -4), round(Ma, 1))

x_coords = np.linspace(0, Lx, nx)
y_coords = np.linspace(-Ly/2, Ly/2, ny)
z_coords = np.linspace(-Lz/2, Lz/2, nz)
interp_u = RegularGridInterpolator((x_coords, y_coords, z_coords), u_box,
                                     bounds_error=False, fill_value=0)

# %%
# --- 1. PRE-ALLOCATION ---
n_stations = len(blade_dict['r'])
n_blades = aerodynamic_params.n_blades

_tables = [{} for _ in range(n_stations)]

dt = np.diff(propeller.acoustic_params.src_times)[0]
time_steps = len(propeller.acoustic_params.src_times)
history = {
    'alpha': np.zeros((time_steps, n_blades, n_stations)),
    'phi':   np.zeros((time_steps, n_blades, n_stations)),
    'W':     np.zeros((time_steps, n_blades, n_stations)),
    'cl':    np.zeros((time_steps, n_blades, n_stations)),
    'cd':    np.zeros((time_steps, n_blades, n_stations)),
    'vi':    np.zeros((time_steps, n_blades, n_stations)),
    'vt':    np.zeros((time_steps, n_blades, n_stations)),
    'dT':    np.zeros((time_steps, n_blades, n_stations)),
    'dQ':    np.zeros((time_steps, n_blades, n_stations)),
    'Re':    np.zeros((time_steps, n_blades, n_stations)),
    'Ma':    np.zeros((time_steps, n_blades, n_stations)),
}

# Global totals (1D arrays)
thrust_history = np.zeros(time_steps)
torque_history = np.zeros(time_steps)

x_accum = 0.0
modelSize = 'xxxlarge'
initial_phi = propeller.solution_data.phi.values

# --- 2. SIMULATION LOOP ---
for time_idx, t in enumerate(propeller.acoustic_params.src_times):
    n_iters = int(np.interp(time_idx, [0, 100], [5, 1]))
    # Advection

    v_advection = np.mean(history['vi'][time_idx-1]) if time_idx > 0 else 0
    x_accum += v_advection * dt
    x_plane = x_accum % Lx 
    
    T_ts = 0
    Q_ts = 0
    
    for b in range(n_blades):
        psi = (aerodynamic_params.omega * t) + (b * 2 * np.pi / n_blades)
        
        for i in range(n_stations):
            r = blade_dict['r'][i]
            dr = blade_dict['dr'][i]
            chord = blade_dict['chord'][i]
            omega_r = aerodynamic_params.omega * r
            
            # Sample Turbulence
            y_pos, z_pos = r * np.cos(psi), r * np.sin(psi)
            u_gust = interp_u([x_plane, y_pos, z_pos])[0]

            # Current Induction (from states)
            vI, vT = history['vi'][time_idx-1, b, i] if time_idx > 0 else initial_phi[i], history['vt'][time_idx-1, b, i] if time_idx > 0 else initial_phi[i]
            for iter in range(n_iters):
                # --- BEMT CALCULATIONS ---
                phi = np.arctan2(vI, vT)
                alpha = blade_dict['twist'][i] - np.degrees(phi)
                W = np.sqrt(vI**2 + vT**2)
                
                # Reynolds/Mach
                Re = aerodynamic_params.rho * W * chord / aerodynamic_params.mu
                Ma = W / aerodynamic_params.a_inf
                
                ReBin = round(Re, -4)
                MaBin = round(Ma, 1)
                key = (ReBin, MaBin)

                # Lazily build the CL/CD vs alpha table for this (ReBin, MaBin)
                if key not in _tables[i]:
                    # Alpha grid in degrees for tabulation
                    alpha_grid = np.linspace(-30.0, 40.0, 141)
                    full_output = asb.Airfoil.get_aero_from_neuralfoil(section_airfoils[i], alpha=alpha_grid, Re=ReBin, mach=MaBin, model_size=modelSize)
                    cl_grid = np.asarray(full_output["CL"], dtype=float)
                    cd_grid = np.asarray(full_output["CD"], dtype=float)
                    _tables[i][key] = (alpha_grid, cl_grid, cd_grid)

                alpha_grid, cl_grid, cd_grid = _tables[i][key]
                # 1D linear interpolation in alpha (degrees)
                cL = np.interp(alpha, alpha_grid, cl_grid)
                cD = np.interp(alpha, alpha_grid, cd_grid)
                if np.isnan(cL) or np.isnan(cD):
                    full_output = asb.Airfoil.get_aero_from_neuralfoil(section_airfoils[i], alpha=alpha, Re=Re, mach=Ma, model_size=modelSize)
                    cL, cD = full_output["CL"].item(), full_output["CD"].item()

                cLPrime = cL * np.cos(phi) - cD * np.sin(phi)
                cDPrime = cL * np.sin(phi) + cD * np.cos(phi)
                
                F = np.clip(prandtlLoss(phi, r), 1e-5, 1.0)
                sigma = aerodynamic_params.n_blades * chord / (2 * np.pi * r)
                k_t = sigma * cLPrime / (4 * F * np.sin(phi) * np.cos(phi)) 
                k_q = sigma * cDPrime / (4 * F * np.sin(phi) * np.cos(phi))
                aPrime = k_q / (1 + k_q)
                vI_new = aerodynamic_params.omega * r * k_t / (1 + k_q) + v_inf + u_gust
                vT_new = aerodynamic_params.omega * r * (1 - aPrime)

                vI += 0.7 * (vI_new - vI)
                vT += 0.7 * (vT_new - vT)

            # --- RECORD TO HISTORY ---
            history['alpha'][time_idx, b, i] = alpha
            history['phi'][time_idx, b, i]   = phi
            history['W'][time_idx, b, i]     = W
            history['cl'][time_idx, b, i]    = cL
            history['cd'][time_idx, b, i]    = cD
            history['vi'][time_idx, b, i]    = vI
            history['vt'][time_idx, b, i]    = vT
            history['Re'][time_idx, b, i]    = Re
            history['Ma'][time_idx, b, i]    = Ma

            dT = 0.5 * aerodynamic_params.rho * W**2 * chord * cLPrime * dr
            dQ = 0.5 * aerodynamic_params.rho * W**2 * chord * cDPrime * r * dr
            
            history['dT'][time_idx, b, i] = dT
            history['dQ'][time_idx, b, i] = dQ
            
            T_ts += dT
            Q_ts += dQ

    thrust_history[time_idx] = T_ts
    torque_history[time_idx] = Q_ts
    
    print(f"Time {t:.3f}s | Total Thrust: {T_ts:.4f}N")
# Out:
# Time 0.000s | Total Thrust: 16.0700N
# Time 0.000s | Total Thrust: 8.1518N
# Time 0.000s | Total Thrust: 8.1392N
# Time 0.000s | Total Thrust: 8.1629N
# Time 0.000s | Total Thrust: 8.1822N
# Time 0.000s | Total Thrust: 8.2320N
# Time 0.000s | Total Thrust: 8.2325N
# Time 0.000s | Total Thrust: 8.2312N
# Time 0.000s | Total Thrust: 8.2255N
# Time 0.000s | Total Thrust: 8.2264N
# Time 0.000s | Total Thrust: 8.2271N
# Time 0.000s | Total Thrust: 8.2193N
# Time 0.000s | Total Thrust: 8.2176N
# Time 0.000s | Total Thrust: 8.2164N
# Time 0.000s | Total Thrust: 8.2110N
# Time 0.000s | Total Thrust: 8.2010N
# Time 0.000s | Total Thrust: 8.1965N
# Time 0.000s | Total Thrust: 8.1906N
# Time 0.001s | Total Thrust: 8.1883N
# Time 0.001s | Total Thrust: 8.1888N
# Time 0.001s | Total Thrust: 8.1862N
# Time 0.001s | Total Thrust: 8.1800N
# Time 0.001s | Total Thrust: 8.1743N
# Time 0.001s | Total Thrust: 8.1671N
# Time 0.001s | Total Thrust: 8.1591N
# Time 0.001s | Total Thrust: 8.1613N
# Time 0.001s | Total Thrust: 8.1650N
# Time 0.001s | Total Thrust: 8.1653N
# Time 0.001s | Total Thrust: 8.1666N
# Time 0.001s | Total Thrust: 8.1708N
# Time 0.001s | Total Thrust: 8.1751N
# Time 0.001s | Total Thrust: 8.1769N
# Time 0.001s | Total Thrust: 8.1743N
# Time 0.001s | Total Thrust: 8.1690N
# Time 0.001s | Total Thrust: 8.1632N
# Time 0.001s | Total Thrust: 8.1589N
# Time 0.001s | Total Thrust: 8.1583N
# Time 0.001s | Total Thrust: 8.1573N
# Time 0.001s | Total Thrust: 8.1555N
# Time 0.001s | Total Thrust: 8.1506N
# Time 0.001s | Total Thrust: 8.1479N
# Time 0.001s | Total Thrust: 8.1434N
# Time 0.001s | Total Thrust: 8.1383N
# Time 0.001s | Total Thrust: 8.1356N
# Time 0.001s | Total Thrust: 8.1295N
# Time 0.001s | Total Thrust: 8.1263N
# Time 0.001s | Total Thrust: 8.1304N
# Time 0.001s | Total Thrust: 8.1449N
# Time 0.001s | Total Thrust: 8.1801N
# Time 0.001s | Total Thrust: 8.1743N
# Time 0.001s | Total Thrust: 8.1667N
# Time 0.001s | Total Thrust: 8.1751N
# Time 0.001s | Total Thrust: 8.1940N
# Time 0.002s | Total Thrust: 8.2050N
# Time 0.002s | Total Thrust: 8.2126N
# Time 0.002s | Total Thrust: 8.2160N
# Time 0.002s | Total Thrust: 8.2124N
# Time 0.002s | Total Thrust: 8.2049N
# Time 0.002s | Total Thrust: 8.1979N
# Time 0.002s | Total Thrust: 8.1914N
# Time 0.002s | Total Thrust: 8.1841N
# Time 0.002s | Total Thrust: 8.1851N
# Time 0.002s | Total Thrust: 8.1937N
# Time 0.002s | Total Thrust: 8.2000N
# Time 0.002s | Total Thrust: 8.2034N
# Time 0.002s | Total Thrust: 8.2059N
# Time 0.002s | Total Thrust: 8.2137N
# Time 0.002s | Total Thrust: 8.2205N
# Time 0.002s | Total Thrust: 8.2260N
# Time 0.002s | Total Thrust: 8.2226N
# Time 0.002s | Total Thrust: 8.2143N
# Time 0.002s | Total Thrust: 8.2046N
# Time 0.002s | Total Thrust: 8.2033N
# Time 0.002s | Total Thrust: 8.2029N
# Time 0.002s | Total Thrust: 8.2034N
# Time 0.002s | Total Thrust: 8.2021N
# Time 0.002s | Total Thrust: 8.2034N
# Time 0.002s | Total Thrust: 8.1980N
# Time 0.002s | Total Thrust: 8.1983N
# Time 0.002s | Total Thrust: 8.2056N
# Time 0.002s | Total Thrust: 8.2106N
# Time 0.002s | Total Thrust: 8.2147N
# Time 0.002s | Total Thrust: 8.2211N
# Time 0.002s | Total Thrust: 8.2265N
# Time 0.002s | Total Thrust: 8.2338N
# Time 0.002s | Total Thrust: 8.2463N
# Time 0.002s | Total Thrust: 8.2597N
# Time 0.002s | Total Thrust: 8.2678N
# Time 0.003s | Total Thrust: 8.2632N
# Time 0.003s | Total Thrust: 8.2434N
# Time 0.003s | Total Thrust: 8.2224N
# Time 0.003s | Total Thrust: 8.2155N
# Time 0.003s | Total Thrust: 8.2159N
# Time 0.003s | Total Thrust: 8.2257N
# Time 0.003s | Total Thrust: 8.2392N
# Time 0.003s | Total Thrust: 8.2403N
# Time 0.003s | Total Thrust: 8.2348N
# Time 0.003s | Total Thrust: 8.2389N
# Time 0.003s | Total Thrust: 8.2645N
# Time 0.003s | Total Thrust: 8.2979N
# Time 0.003s | Total Thrust: 8.3043N
# Time 0.003s | Total Thrust: 8.3093N
# Time 0.003s | Total Thrust: 8.3219N
# Time 0.003s | Total Thrust: 8.3243N
# Time 0.003s | Total Thrust: 8.3254N
# Time 0.003s | Total Thrust: 8.3262N
# Time 0.003s | Total Thrust: 8.3288N
# Time 0.003s | Total Thrust: 8.3318N
# Time 0.003s | Total Thrust: 8.3264N
# Time 0.003s | Total Thrust: 8.3145N
# Time 0.003s | Total Thrust: 8.3070N
# Time 0.003s | Total Thrust: 8.2968N
# Time 0.003s | Total Thrust: 8.3004N
# Time 0.003s | Total Thrust: 8.3004N
# Time 0.003s | Total Thrust: 8.2997N
# Time 0.003s | Total Thrust: 8.2963N
# Time 0.003s | Total Thrust: 8.2906N
# Time 0.003s | Total Thrust: 8.2846N
# Time 0.003s | Total Thrust: 8.2814N
# Time 0.003s | Total Thrust: 8.2790N
# Time 0.003s | Total Thrust: 8.2845N
# Time 0.003s | Total Thrust: 8.2987N
# Time 0.003s | Total Thrust: 8.3093N
# Time 0.004s | Total Thrust: 8.3101N
# Time 0.004s | Total Thrust: 8.3080N
# Time 0.004s | Total Thrust: 8.2999N
# Time 0.004s | Total Thrust: 8.2925N
# Time 0.004s | Total Thrust: 8.2867N
# Time 0.004s | Total Thrust: 8.2805N
# Time 0.004s | Total Thrust: 8.2677N
# Time 0.004s | Total Thrust: 8.2643N
# Time 0.004s | Total Thrust: 8.2710N
# Time 0.004s | Total Thrust: 8.2804N
# Time 0.004s | Total Thrust: 8.2862N
# Time 0.004s | Total Thrust: 8.2848N
# Time 0.004s | Total Thrust: 8.2887N
# Time 0.004s | Total Thrust: 8.2957N
# Time 0.004s | Total Thrust: 8.2972N
# Time 0.004s | Total Thrust: 8.3047N
# Time 0.004s | Total Thrust: 8.2989N
# Time 0.004s | Total Thrust: 8.2911N
# Time 0.004s | Total Thrust: 8.2813N
# Time 0.004s | Total Thrust: 8.2738N
# Time 0.004s | Total Thrust: 8.2789N
# Time 0.004s | Total Thrust: 8.2796N
# Time 0.004s | Total Thrust: 8.2867N
# Time 0.004s | Total Thrust: 8.2812N
# Time 0.004s | Total Thrust: 8.2781N
# Time 0.004s | Total Thrust: 8.2681N
# Time 0.004s | Total Thrust: 8.2584N
# Time 0.004s | Total Thrust: 8.2602N
# Time 0.004s | Total Thrust: 8.2636N
# Time 0.004s | Total Thrust: 8.2690N
# Time 0.004s | Total Thrust: 8.2776N
# Time 0.004s | Total Thrust: 8.2806N
# Time 0.004s | Total Thrust: 8.2782N
# Time 0.004s | Total Thrust: 8.2785N
# Time 0.004s | Total Thrust: 8.2819N
# Time 0.005s | Total Thrust: 8.2854N
# Time 0.005s | Total Thrust: 8.2895N
# Time 0.005s | Total Thrust: 8.2957N
# Time 0.005s | Total Thrust: 8.2987N
# Time 0.005s | Total Thrust: 8.2937N
# Time 0.005s | Total Thrust: 8.2942N
# Time 0.005s | Total Thrust: 8.2943N
# Time 0.005s | Total Thrust: 8.2968N
# Time 0.005s | Total Thrust: 8.2947N
# Time 0.005s | Total Thrust: 8.3010N
# Time 0.005s | Total Thrust: 8.3025N
# Time 0.005s | Total Thrust: 8.3057N
# Time 0.005s | Total Thrust: 8.3092N
# Time 0.005s | Total Thrust: 8.3112N
# Time 0.005s | Total Thrust: 8.3084N
# Time 0.005s | Total Thrust: 8.3081N
# Time 0.005s | Total Thrust: 8.3093N
# Time 0.005s | Total Thrust: 8.3054N
# Time 0.005s | Total Thrust: 8.2973N
# Time 0.005s | Total Thrust: 8.2851N
# Time 0.005s | Total Thrust: 8.2751N
# Time 0.005s | Total Thrust: 8.2729N
# Time 0.005s | Total Thrust: 8.2794N
# Time 0.005s | Total Thrust: 8.2782N
# Time 0.005s | Total Thrust: 8.2793N
# Time 0.005s | Total Thrust: 8.2785N
# Time 0.005s | Total Thrust: 8.2843N
# Time 0.005s | Total Thrust: 8.2764N
# Time 0.005s | Total Thrust: 8.2735N
# Time 0.005s | Total Thrust: 8.2683N
# Time 0.005s | Total Thrust: 8.2575N
# Time 0.005s | Total Thrust: 8.2469N
# Time 0.005s | Total Thrust: 8.2394N
# Time 0.005s | Total Thrust: 8.2325N
# Time 0.005s | Total Thrust: 8.2241N
# Time 0.006s | Total Thrust: 8.2229N
# Time 0.006s | Total Thrust: 8.2164N
# Time 0.006s | Total Thrust: 8.2128N
# Time 0.006s | Total Thrust: 8.2171N
# Time 0.006s | Total Thrust: 8.2191N
# Time 0.006s | Total Thrust: 8.2190N
# Time 0.006s | Total Thrust: 8.2216N
# Time 0.006s | Total Thrust: 8.2287N
# Time 0.006s | Total Thrust: 8.2386N
# Time 0.006s | Total Thrust: 8.2380N
# Time 0.006s | Total Thrust: 8.2386N
# Time 0.006s | Total Thrust: 8.2345N
# Time 0.006s | Total Thrust: 8.2282N
# Time 0.006s | Total Thrust: 8.2181N
# Time 0.006s | Total Thrust: 8.2069N
# Time 0.006s | Total Thrust: 8.2102N
# Time 0.006s | Total Thrust: 8.2110N
# Time 0.006s | Total Thrust: 8.2216N
# Time 0.006s | Total Thrust: 8.2301N
# Time 0.006s | Total Thrust: 8.2318N
# Time 0.006s | Total Thrust: 8.2392N
# Time 0.006s | Total Thrust: 8.2413N
# Time 0.006s | Total Thrust: 8.2443N
# Time 0.006s | Total Thrust: 8.2450N
# Time 0.006s | Total Thrust: 8.2492N
# Time 0.006s | Total Thrust: 8.2574N
# Time 0.006s | Total Thrust: 8.2616N
# Time 0.006s | Total Thrust: 8.2518N
# Time 0.006s | Total Thrust: 8.2520N
# Time 0.006s | Total Thrust: 8.2599N
# Time 0.006s | Total Thrust: 8.2713N
# Time 0.006s | Total Thrust: 8.2770N
# Time 0.006s | Total Thrust: 8.2748N
# Time 0.006s | Total Thrust: 8.2688N
# Time 0.006s | Total Thrust: 8.2692N
# Time 0.007s | Total Thrust: 8.2730N
# Time 0.007s | Total Thrust: 8.2736N
# Time 0.007s | Total Thrust: 8.2702N
# Time 0.007s | Total Thrust: 8.2714N
# Time 0.007s | Total Thrust: 8.2721N
# Time 0.007s | Total Thrust: 8.2737N
# Time 0.007s | Total Thrust: 8.2672N
# Time 0.007s | Total Thrust: 8.2590N
# Time 0.007s | Total Thrust: 8.2666N
# Time 0.007s | Total Thrust: 8.2678N
# Time 0.007s | Total Thrust: 8.2671N
# Time 0.007s | Total Thrust: 8.2687N
# Time 0.007s | Total Thrust: 8.2660N
# Time 0.007s | Total Thrust: 8.2662N
# Time 0.007s | Total Thrust: 8.2588N
# Time 0.007s | Total Thrust: 8.2572N
# Time 0.007s | Total Thrust: 8.2617N
# Time 0.007s | Total Thrust: 8.2662N
# Time 0.007s | Total Thrust: 8.2619N
# Time 0.007s | Total Thrust: 8.2509N
# Time 0.007s | Total Thrust: 8.2480N
# Time 0.007s | Total Thrust: 8.2539N
# Time 0.007s | Total Thrust: 8.2613N
# Time 0.007s | Total Thrust: 8.2694N
# Time 0.007s | Total Thrust: 8.2769N
# Time 0.007s | Total Thrust: 8.2842N
# Time 0.007s | Total Thrust: 8.2798N
# Time 0.007s | Total Thrust: 8.2686N
# Time 0.007s | Total Thrust: 8.2682N
# Time 0.007s | Total Thrust: 8.2692N
# Time 0.007s | Total Thrust: 8.2676N
# Time 0.007s | Total Thrust: 8.2625N
# Time 0.007s | Total Thrust: 8.2569N
# Time 0.007s | Total Thrust: 8.2581N
# Time 0.007s | Total Thrust: 8.2594N
# Time 0.008s | Total Thrust: 8.2631N
# Time 0.008s | Total Thrust: 8.2707N
# Time 0.008s | Total Thrust: 8.2780N
# Time 0.008s | Total Thrust: 8.2925N
# Time 0.008s | Total Thrust: 8.3012N
# Time 0.008s | Total Thrust: 8.3056N
# Time 0.008s | Total Thrust: 8.3047N
# Time 0.008s | Total Thrust: 8.3071N
# Time 0.008s | Total Thrust: 8.3055N
# Time 0.008s | Total Thrust: 8.3005N
# Time 0.008s | Total Thrust: 8.2921N
# Time 0.008s | Total Thrust: 8.2854N
# Time 0.008s | Total Thrust: 8.2803N
# Time 0.008s | Total Thrust: 8.2710N
# Time 0.008s | Total Thrust: 8.2588N
# Time 0.008s | Total Thrust: 8.2553N
# Time 0.008s | Total Thrust: 8.2561N
# Time 0.008s | Total Thrust: 8.2598N
# Time 0.008s | Total Thrust: 8.2698N
# Time 0.008s | Total Thrust: 8.2771N
# Time 0.008s | Total Thrust: 8.2793N
# Time 0.008s | Total Thrust: 8.2795N
# Time 0.008s | Total Thrust: 8.2873N
# Time 0.008s | Total Thrust: 8.2991N
# Time 0.008s | Total Thrust: 8.3050N
# Time 0.008s | Total Thrust: 8.3087N
# Time 0.008s | Total Thrust: 8.3082N
# Time 0.008s | Total Thrust: 8.3030N
# Time 0.008s | Total Thrust: 8.2935N
# Time 0.008s | Total Thrust: 8.2855N
# Time 0.008s | Total Thrust: 8.2857N
# Time 0.008s | Total Thrust: 8.2816N
# Time 0.008s | Total Thrust: 8.2811N
# Time 0.008s | Total Thrust: 8.2803N
# Time 0.008s | Total Thrust: 8.2910N
# Time 0.009s | Total Thrust: 8.3023N
# Time 0.009s | Total Thrust: 8.2819N
# Time 0.009s | Total Thrust: 8.2879N
# Time 0.009s | Total Thrust: 8.2946N
# Time 0.009s | Total Thrust: 8.3023N
# Time 0.009s | Total Thrust: 8.3112N
# Time 0.009s | Total Thrust: 8.3366N
# Time 0.009s | Total Thrust: 8.3446N
# Time 0.009s | Total Thrust: 8.3421N
# Time 0.009s | Total Thrust: 8.3324N
# Time 0.009s | Total Thrust: 8.3275N
# Time 0.009s | Total Thrust: 8.3355N
# Time 0.009s | Total Thrust: 8.3353N
# Time 0.009s | Total Thrust: 8.3278N
# Time 0.009s | Total Thrust: 8.3199N
# Time 0.009s | Total Thrust: 8.3058N
# Time 0.009s | Total Thrust: 8.3031N
# Time 0.009s | Total Thrust: 8.3065N
# Time 0.009s | Total Thrust: 8.3108N
# Time 0.009s | Total Thrust: 8.3162N
# Time 0.009s | Total Thrust: 8.3165N
# Time 0.009s | Total Thrust: 8.3176N
# Time 0.009s | Total Thrust: 8.3131N
# Time 0.009s | Total Thrust: 8.3063N
# Time 0.009s | Total Thrust: 8.3005N
# Time 0.009s | Total Thrust: 8.2980N
# Time 0.009s | Total Thrust: 8.3048N
# Time 0.009s | Total Thrust: 8.3131N
# Time 0.009s | Total Thrust: 8.3187N
# Time 0.009s | Total Thrust: 8.3187N
# Time 0.009s | Total Thrust: 8.3131N
# Time 0.009s | Total Thrust: 8.3148N
# Time 0.009s | Total Thrust: 8.3120N
# Time 0.009s | Total Thrust: 8.3115N
# Time 0.009s | Total Thrust: 8.3101N
# Time 0.010s | Total Thrust: 8.3091N
# Time 0.010s | Total Thrust: 8.3074N
# Time 0.010s | Total Thrust: 8.3063N
# Time 0.010s | Total Thrust: 8.3068N
# Time 0.010s | Total Thrust: 8.3088N
# Time 0.010s | Total Thrust: 8.3174N
# Time 0.010s | Total Thrust: 8.3227N
# Time 0.010s | Total Thrust: 8.3284N
# Time 0.010s | Total Thrust: 8.3292N
# Time 0.010s | Total Thrust: 8.3322N
# Time 0.010s | Total Thrust: 8.3345N
# Time 0.010s | Total Thrust: 8.3323N
# Time 0.010s | Total Thrust: 8.3167N
# Time 0.010s | Total Thrust: 8.3041N
# Time 0.010s | Total Thrust: 8.2995N
# Time 0.010s | Total Thrust: 8.3033N
# Time 0.010s | Total Thrust: 8.3170N
# Time 0.010s | Total Thrust: 8.3237N
# Time 0.010s | Total Thrust: 8.3242N
# Time 0.010s | Total Thrust: 8.3201N
# Time 0.010s | Total Thrust: 8.3323N
# Time 0.010s | Total Thrust: 8.3360N
# Time 0.010s | Total Thrust: 8.3375N
# Time 0.010s | Total Thrust: 8.3295N
# Time 0.010s | Total Thrust: 8.3262N
# Time 0.010s | Total Thrust: 8.3342N
# Time 0.010s | Total Thrust: 8.3386N
# Time 0.010s | Total Thrust: 8.3491N
# Time 0.010s | Total Thrust: 8.3571N
# Time 0.010s | Total Thrust: 8.3581N
# Time 0.010s | Total Thrust: 8.3565N
# Time 0.010s | Total Thrust: 8.3567N
# Time 0.010s | Total Thrust: 8.3539N
# Time 0.010s | Total Thrust: 8.3540N
# Time 0.010s | Total Thrust: 8.3552N
# Time 0.011s | Total Thrust: 8.3558N
# Time 0.011s | Total Thrust: 8.3501N
# Time 0.011s | Total Thrust: 8.3445N
# Time 0.011s | Total Thrust: 8.3408N
# Time 0.011s | Total Thrust: 8.3359N
# Time 0.011s | Total Thrust: 8.3274N
# Time 0.011s | Total Thrust: 8.3263N
# Time 0.011s | Total Thrust: 8.3237N
# Time 0.011s | Total Thrust: 8.3253N
# Time 0.011s | Total Thrust: 8.3242N
# Time 0.011s | Total Thrust: 8.3227N
# Time 0.011s | Total Thrust: 8.3197N
# Time 0.011s | Total Thrust: 8.3120N
# Time 0.011s | Total Thrust: 8.3163N
# Time 0.011s | Total Thrust: 8.3228N
# Time 0.011s | Total Thrust: 8.3273N
# Time 0.011s | Total Thrust: 8.3318N
# Time 0.011s | Total Thrust: 8.3315N
# Time 0.011s | Total Thrust: 8.3311N
# Time 0.011s | Total Thrust: 8.3280N
# Time 0.011s | Total Thrust: 8.3292N
# Time 0.011s | Total Thrust: 8.3327N
# Time 0.011s | Total Thrust: 8.3320N
# Time 0.011s | Total Thrust: 8.3312N
# Time 0.011s | Total Thrust: 8.3152N
# Time 0.011s | Total Thrust: 8.2919N
# Time 0.011s | Total Thrust: 8.2855N
# Time 0.011s | Total Thrust: 8.2848N
# Time 0.011s | Total Thrust: 8.2885N
# Time 0.011s | Total Thrust: 8.2803N
# Time 0.011s | Total Thrust: 8.2757N
# Time 0.011s | Total Thrust: 8.2695N
# Time 0.011s | Total Thrust: 8.2678N
# Time 0.011s | Total Thrust: 8.2653N
# Time 0.011s | Total Thrust: 8.2692N
# Time 0.012s | Total Thrust: 8.2704N
# Time 0.012s | Total Thrust: 8.2726N
# Time 0.012s | Total Thrust: 8.2779N
# Time 0.012s | Total Thrust: 8.2858N
# Time 0.012s | Total Thrust: 8.2950N
# Time 0.012s | Total Thrust: 8.2979N
# Time 0.012s | Total Thrust: 8.2941N
# Time 0.012s | Total Thrust: 8.2966N
# Time 0.012s | Total Thrust: 8.2982N
# Time 0.012s | Total Thrust: 8.2972N
# Time 0.012s | Total Thrust: 8.3062N
# Time 0.012s | Total Thrust: 8.3078N
# Time 0.012s | Total Thrust: 8.3039N
# Time 0.012s | Total Thrust: 8.2962N
# Time 0.012s | Total Thrust: 8.2905N
# Time 0.012s | Total Thrust: 8.2846N
# Time 0.012s | Total Thrust: 8.2883N
# Time 0.012s | Total Thrust: 8.2885N
# Time 0.012s | Total Thrust: 8.2862N
# Time 0.012s | Total Thrust: 8.2870N
# Time 0.012s | Total Thrust: 8.2860N
# Time 0.012s | Total Thrust: 8.2785N
# Time 0.012s | Total Thrust: 8.2768N
# Time 0.012s | Total Thrust: 8.2678N
# Time 0.012s | Total Thrust: 8.2680N
# Time 0.012s | Total Thrust: 8.2619N
# Time 0.012s | Total Thrust: 8.2532N
# Time 0.012s | Total Thrust: 8.2525N
# Time 0.012s | Total Thrust: 8.2572N
# Time 0.012s | Total Thrust: 8.2587N
# Time 0.012s | Total Thrust: 8.2573N
# Time 0.012s | Total Thrust: 8.2557N
# Time 0.012s | Total Thrust: 8.2576N
# Time 0.012s | Total Thrust: 8.2623N
# Time 0.012s | Total Thrust: 8.2616N
# Time 0.013s | Total Thrust: 8.2708N
# Time 0.013s | Total Thrust: 8.2725N
# Time 0.013s | Total Thrust: 8.2725N
# Time 0.013s | Total Thrust: 8.2718N
# Time 0.013s | Total Thrust: 8.2728N
# Time 0.013s | Total Thrust: 8.2725N
# Time 0.013s | Total Thrust: 8.2715N
# Time 0.013s | Total Thrust: 8.2749N
# Time 0.013s | Total Thrust: 8.2855N
# Time 0.013s | Total Thrust: 8.2929N
# Time 0.013s | Total Thrust: 8.2933N
# Time 0.013s | Total Thrust: 8.3003N
# Time 0.013s | Total Thrust: 8.2959N
# Time 0.013s | Total Thrust: 8.2919N
# Time 0.013s | Total Thrust: 8.2850N
# Time 0.013s | Total Thrust: 8.2841N
# Time 0.013s | Total Thrust: 8.2817N
# Time 0.013s | Total Thrust: 8.2923N
# Time 0.013s | Total Thrust: 8.2954N
# Time 0.013s | Total Thrust: 8.2925N
# Time 0.013s | Total Thrust: 8.2864N
# Time 0.013s | Total Thrust: 8.2901N
# Time 0.013s | Total Thrust: 8.2958N
# Time 0.013s | Total Thrust: 8.2958N
# Time 0.013s | Total Thrust: 8.2903N
# Time 0.013s | Total Thrust: 8.2799N
# Time 0.013s | Total Thrust: 8.2681N
# Time 0.013s | Total Thrust: 8.2739N
# Time 0.013s | Total Thrust: 8.2737N
# Time 0.013s | Total Thrust: 8.2663N
# Time 0.013s | Total Thrust: 8.2635N
# Time 0.013s | Total Thrust: 8.2714N
# Time 0.013s | Total Thrust: 8.2697N
# Time 0.013s | Total Thrust: 8.2717N
# Time 0.013s | Total Thrust: 8.2676N
# Time 0.014s | Total Thrust: 8.2737N
# Time 0.014s | Total Thrust: 8.2773N
# Time 0.014s | Total Thrust: 8.2845N
# Time 0.014s | Total Thrust: 8.2859N
# Time 0.014s | Total Thrust: 8.2876N
# Time 0.014s | Total Thrust: 8.2912N
# Time 0.014s | Total Thrust: 8.2956N
# Time 0.014s | Total Thrust: 8.2941N
# Time 0.014s | Total Thrust: 8.2975N
# Time 0.014s | Total Thrust: 8.3048N
# Time 0.014s | Total Thrust: 8.3153N
# Time 0.014s | Total Thrust: 8.3224N
# Time 0.014s | Total Thrust: 8.3258N
# Time 0.014s | Total Thrust: 8.3261N
# Time 0.014s | Total Thrust: 8.3325N
# Time 0.014s | Total Thrust: 8.3310N
# Time 0.014s | Total Thrust: 8.3424N
# Time 0.014s | Total Thrust: 8.3578N
# Time 0.014s | Total Thrust: 8.3570N
# Time 0.014s | Total Thrust: 8.3664N
# Time 0.014s | Total Thrust: 8.3680N
# Time 0.014s | Total Thrust: 8.3724N
# Time 0.014s | Total Thrust: 8.3770N
# Time 0.014s | Total Thrust: 8.3733N
# Time 0.014s | Total Thrust: 8.3728N
# Time 0.014s | Total Thrust: 8.3759N
# Time 0.014s | Total Thrust: 8.3840N
# Time 0.014s | Total Thrust: 8.3824N
# Time 0.014s | Total Thrust: 8.3789N
# Time 0.014s | Total Thrust: 8.3665N
# Time 0.014s | Total Thrust: 8.3632N
# Time 0.014s | Total Thrust: 8.3525N
# Time 0.014s | Total Thrust: 8.3476N
# Time 0.014s | Total Thrust: 8.3439N
# Time 0.014s | Total Thrust: 8.3414N
# Time 0.015s | Total Thrust: 8.3319N
# Time 0.015s | Total Thrust: 8.3267N
# Time 0.015s | Total Thrust: 8.3340N
# Time 0.015s | Total Thrust: 8.3383N
# Time 0.015s | Total Thrust: 8.3430N
# Time 0.015s | Total Thrust: 8.3429N
# Time 0.015s | Total Thrust: 8.3460N
# Time 0.015s | Total Thrust: 8.3455N
# Time 0.015s | Total Thrust: 8.3519N
# Time 0.015s | Total Thrust: 8.3531N
# Time 0.015s | Total Thrust: 8.3511N
# Time 0.015s | Total Thrust: 8.3527N
# Time 0.015s | Total Thrust: 8.3496N
# Time 0.015s | Total Thrust: 8.3481N
# Time 0.015s | Total Thrust: 8.3492N
# Time 0.015s | Total Thrust: 8.3467N
# Time 0.015s | Total Thrust: 8.3429N
# Time 0.015s | Total Thrust: 8.3326N
# Time 0.015s | Total Thrust: 8.3382N
# Time 0.015s | Total Thrust: 8.3443N
# Time 0.015s | Total Thrust: 8.3514N
# Time 0.015s | Total Thrust: 8.3487N
# Time 0.015s | Total Thrust: 8.3481N
# Time 0.015s | Total Thrust: 8.3410N
# Time 0.015s | Total Thrust: 8.3339N
# Time 0.015s | Total Thrust: 8.3271N
# Time 0.015s | Total Thrust: 8.3276N
# Time 0.015s | Total Thrust: 8.3298N
# Time 0.015s | Total Thrust: 8.3349N
# Time 0.015s | Total Thrust: 8.3317N
# Time 0.015s | Total Thrust: 8.3308N
# Time 0.015s | Total Thrust: 8.3318N
# Time 0.015s | Total Thrust: 8.3293N
# Time 0.015s | Total Thrust: 8.3212N
# Time 0.015s | Total Thrust: 8.3191N
# Time 0.016s | Total Thrust: 8.3243N
# Time 0.016s | Total Thrust: 8.3318N
# Time 0.016s | Total Thrust: 8.3448N
# Time 0.016s | Total Thrust: 8.3487N
# Time 0.016s | Total Thrust: 8.3514N
# Time 0.016s | Total Thrust: 8.3505N
# Time 0.016s | Total Thrust: 8.3559N
# Time 0.016s | Total Thrust: 8.3633N
# Time 0.016s | Total Thrust: 8.3753N
# Time 0.016s | Total Thrust: 8.3784N
# Time 0.016s | Total Thrust: 8.3764N
# Time 0.016s | Total Thrust: 8.3763N
# Time 0.016s | Total Thrust: 8.3786N
# Time 0.016s | Total Thrust: 8.3836N
# Time 0.016s | Total Thrust: 8.3863N
# Time 0.016s | Total Thrust: 8.3881N
# Time 0.016s | Total Thrust: 8.3843N
# Time 0.016s | Total Thrust: 8.3795N
# Time 0.016s | Total Thrust: 8.3704N
# Time 0.016s | Total Thrust: 8.3681N
# Time 0.016s | Total Thrust: 8.3625N
# Time 0.016s | Total Thrust: 8.3501N
# Time 0.016s | Total Thrust: 8.3270N
# Time 0.016s | Total Thrust: 8.3039N
# Time 0.016s | Total Thrust: 8.2912N
# Time 0.016s | Total Thrust: 8.2800N
# Time 0.016s | Total Thrust: 8.2776N
# Time 0.016s | Total Thrust: 8.2800N
# Time 0.016s | Total Thrust: 8.2745N
# Time 0.016s | Total Thrust: 8.2751N
# Time 0.016s | Total Thrust: 8.2662N
# Time 0.016s | Total Thrust: 8.2569N
# Time 0.016s | Total Thrust: 8.2508N
# Time 0.016s | Total Thrust: 8.2525N
# Time 0.016s | Total Thrust: 8.2688N
# Time 0.017s | Total Thrust: 8.2764N
# Time 0.017s | Total Thrust: 8.2846N
# Time 0.017s | Total Thrust: 8.2903N
# Time 0.017s | Total Thrust: 8.2963N
# Time 0.017s | Total Thrust: 8.2967N
# Time 0.017s | Total Thrust: 8.2970N
# Time 0.017s | Total Thrust: 8.3040N
# Time 0.017s | Total Thrust: 8.3120N
# Time 0.017s | Total Thrust: 8.3168N
# Time 0.017s | Total Thrust: 8.3302N
# Time 0.017s | Total Thrust: 8.3415N
# Time 0.017s | Total Thrust: 8.3443N
# Time 0.017s | Total Thrust: 8.3457N
# Time 0.017s | Total Thrust: 8.3481N
# Time 0.017s | Total Thrust: 8.3579N
# Time 0.017s | Total Thrust: 8.3555N
# Time 0.017s | Total Thrust: 8.3545N
# Time 0.017s | Total Thrust: 8.3592N
# Time 0.017s | Total Thrust: 8.3670N
# Time 0.017s | Total Thrust: 8.3640N
# Time 0.017s | Total Thrust: 8.3697N
# Time 0.017s | Total Thrust: 8.3794N
# Time 0.017s | Total Thrust: 8.3952N
# Time 0.017s | Total Thrust: 8.3985N
# Time 0.017s | Total Thrust: 8.4021N
# Time 0.017s | Total Thrust: 8.3966N
# Time 0.017s | Total Thrust: 8.3980N
# Time 0.017s | Total Thrust: 8.3852N
# Time 0.017s | Total Thrust: 8.3882N
# Time 0.017s | Total Thrust: 8.3781N
# Time 0.017s | Total Thrust: 8.3696N
# Time 0.017s | Total Thrust: 8.3619N
# Time 0.017s | Total Thrust: 8.3643N
# Time 0.017s | Total Thrust: 8.3640N
# Time 0.017s | Total Thrust: 8.3640N
# Time 0.018s | Total Thrust: 8.3631N
# Time 0.018s | Total Thrust: 8.3590N
# Time 0.018s | Total Thrust: 8.3519N
# Time 0.018s | Total Thrust: 8.3492N
# Time 0.018s | Total Thrust: 8.3459N
# Time 0.018s | Total Thrust: 8.3392N
# Time 0.018s | Total Thrust: 8.3303N
# Time 0.018s | Total Thrust: 8.3158N
# Time 0.018s | Total Thrust: 8.3062N
# Time 0.018s | Total Thrust: 8.2965N
# Time 0.018s | Total Thrust: 8.2847N
# Time 0.018s | Total Thrust: 8.2788N
# Time 0.018s | Total Thrust: 8.2865N
# Time 0.018s | Total Thrust: 8.2964N
# Time 0.018s | Total Thrust: 8.3129N
# Time 0.018s | Total Thrust: 8.3187N
# Time 0.018s | Total Thrust: 8.3255N
# Time 0.018s | Total Thrust: 8.3289N
# Time 0.018s | Total Thrust: 8.3313N
# Time 0.018s | Total Thrust: 8.3348N
# Time 0.018s | Total Thrust: 8.3365N
# Time 0.018s | Total Thrust: 8.3320N
# Time 0.018s | Total Thrust: 8.3212N
# Time 0.018s | Total Thrust: 8.2995N
# Time 0.018s | Total Thrust: 8.2859N
# Time 0.018s | Total Thrust: 8.2885N
# Time 0.018s | Total Thrust: 8.2829N
# Time 0.018s | Total Thrust: 8.2804N
# Time 0.018s | Total Thrust: 8.2748N
# Time 0.018s | Total Thrust: 8.2821N
# Time 0.018s | Total Thrust: 8.2955N
# Time 0.018s | Total Thrust: 8.3037N
# Time 0.018s | Total Thrust: 8.3092N
# Time 0.018s | Total Thrust: 8.3107N
# Time 0.018s | Total Thrust: 8.3074N
# Time 0.019s | Total Thrust: 8.2970N
# Time 0.019s | Total Thrust: 8.2947N
# Time 0.019s | Total Thrust: 8.2975N
# Time 0.019s | Total Thrust: 8.3014N
# Time 0.019s | Total Thrust: 8.3046N
# Time 0.019s | Total Thrust: 8.3071N
# Time 0.019s | Total Thrust: 8.3076N
# Time 0.019s | Total Thrust: 8.3079N
# Time 0.019s | Total Thrust: 8.2961N
# Time 0.019s | Total Thrust: 8.2784N
# Time 0.019s | Total Thrust: 8.2656N
# Time 0.019s | Total Thrust: 8.2742N
# Time 0.019s | Total Thrust: 8.2882N
# Time 0.019s | Total Thrust: 8.2969N
# Time 0.019s | Total Thrust: 8.2989N
# Time 0.019s | Total Thrust: 8.3100N
# Time 0.019s | Total Thrust: 8.3058N
# Time 0.019s | Total Thrust: 8.3005N
# Time 0.019s | Total Thrust: 8.2876N
# Time 0.019s | Total Thrust: 8.2760N
# Time 0.019s | Total Thrust: 8.2670N
# Time 0.019s | Total Thrust: 8.2654N
# Time 0.019s | Total Thrust: 8.2655N
# Time 0.019s | Total Thrust: 8.2685N
# Time 0.019s | Total Thrust: 8.2825N
# Time 0.019s | Total Thrust: 8.3135N
# Time 0.019s | Total Thrust: 8.3282N
# Time 0.019s | Total Thrust: 8.3313N
# Time 0.019s | Total Thrust: 8.3352N
# Time 0.019s | Total Thrust: 8.3363N
# Time 0.019s | Total Thrust: 8.3382N
# Time 0.019s | Total Thrust: 8.3389N
# Time 0.019s | Total Thrust: 8.3400N
# Time 0.019s | Total Thrust: 8.3436N
# Time 0.019s | Total Thrust: 8.3441N
# Time 0.020s | Total Thrust: 8.3499N
# Time 0.020s | Total Thrust: 8.3554N
# Time 0.020s | Total Thrust: 8.3732N
# Time 0.020s | Total Thrust: 8.3824N
# Time 0.020s | Total Thrust: 8.3880N
# Time 0.020s | Total Thrust: 8.3840N
# Time 0.020s | Total Thrust: 8.3863N
# Time 0.020s | Total Thrust: 8.3851N
# Time 0.020s | Total Thrust: 8.3765N
# Time 0.020s | Total Thrust: 8.3673N
# Time 0.020s | Total Thrust: 8.3667N
# Time 0.020s | Total Thrust: 8.3623N
# Time 0.020s | Total Thrust: 8.3596N
# Time 0.020s | Total Thrust: 8.3582N
# Time 0.020s | Total Thrust: 8.3686N
# Time 0.020s | Total Thrust: 8.3674N
# Time 0.020s | Total Thrust: 8.3646N
# Time 0.020s | Total Thrust: 8.3580N
# Time 0.020s | Total Thrust: 8.3475N
# Time 0.020s | Total Thrust: 8.3366N
# Time 0.020s | Total Thrust: 8.3335N
# Time 0.020s | Total Thrust: 8.3185N
# Time 0.020s | Total Thrust: 8.2957N
# Time 0.020s | Total Thrust: 8.2985N
# Time 0.020s | Total Thrust: 8.2915N
# Time 0.020s | Total Thrust: 8.2836N
# Time 0.020s | Total Thrust: 8.2835N
# Time 0.020s | Total Thrust: 8.2857N
# Time 0.020s | Total Thrust: 8.2855N
# Time 0.020s | Total Thrust: 8.2778N
# Time 0.020s | Total Thrust: 8.2744N
# Time 0.020s | Total Thrust: 8.2722N
# Time 0.020s | Total Thrust: 8.2670N
# Time 0.020s | Total Thrust: 8.2593N
# Time 0.020s | Total Thrust: 8.2626N
# Time 0.021s | Total Thrust: 8.2634N
# Time 0.021s | Total Thrust: 8.2602N
# Time 0.021s | Total Thrust: 8.2574N
# Time 0.021s | Total Thrust: 8.2586N
# Time 0.021s | Total Thrust: 8.2600N
# Time 0.021s | Total Thrust: 8.2587N
# Time 0.021s | Total Thrust: 8.2523N
# Time 0.021s | Total Thrust: 8.2487N
# Time 0.021s | Total Thrust: 8.2498N
# Time 0.021s | Total Thrust: 8.2533N
# Time 0.021s | Total Thrust: 8.2486N
# Time 0.021s | Total Thrust: 8.2477N
# Time 0.021s | Total Thrust: 8.2563N
# Time 0.021s | Total Thrust: 8.2664N
# Time 0.021s | Total Thrust: 8.2789N
# Time 0.021s | Total Thrust: 8.2898N
# Time 0.021s | Total Thrust: 8.3110N
# Time 0.021s | Total Thrust: 8.3267N
# Time 0.021s | Total Thrust: 8.3434N
# Time 0.021s | Total Thrust: 8.3433N
# Time 0.021s | Total Thrust: 8.3347N
# Time 0.021s | Total Thrust: 8.3268N
# Time 0.021s | Total Thrust: 8.3184N
# Time 0.021s | Total Thrust: 8.3090N
# Time 0.021s | Total Thrust: 8.3000N
# Time 0.021s | Total Thrust: 8.2985N
# Time 0.021s | Total Thrust: 8.2939N
# Time 0.021s | Total Thrust: 8.2922N
# Time 0.021s | Total Thrust: 8.2974N
# Time 0.021s | Total Thrust: 8.3062N
# Time 0.021s | Total Thrust: 8.3096N
# Time 0.021s | Total Thrust: 8.3044N
# Time 0.021s | Total Thrust: 8.3079N
# Time 0.021s | Total Thrust: 8.3050N
# Time 0.021s | Total Thrust: 8.3110N
# Time 0.022s | Total Thrust: 8.3139N
# Time 0.022s | Total Thrust: 8.3147N
# Time 0.022s | Total Thrust: 8.3096N
# Time 0.022s | Total Thrust: 8.3119N
# Time 0.022s | Total Thrust: 8.3147N
# Time 0.022s | Total Thrust: 8.3140N
# Time 0.022s | Total Thrust: 8.3074N
# Time 0.022s | Total Thrust: 8.3049N
# Time 0.022s | Total Thrust: 8.3044N
# Time 0.022s | Total Thrust: 8.2990N
# Time 0.022s | Total Thrust: 8.2964N
# Time 0.022s | Total Thrust: 8.2959N
# Time 0.022s | Total Thrust: 8.2916N
# Time 0.022s | Total Thrust: 8.2976N
# Time 0.022s | Total Thrust: 8.2974N
# Time 0.022s | Total Thrust: 8.3000N
# Time 0.022s | Total Thrust: 8.2993N
# Time 0.022s | Total Thrust: 8.2941N
# Time 0.022s | Total Thrust: 8.2881N
# Time 0.022s | Total Thrust: 8.2790N
# Time 0.022s | Total Thrust: 8.2645N
# Time 0.022s | Total Thrust: 8.2481N
# Time 0.022s | Total Thrust: 8.2338N
# Time 0.022s | Total Thrust: 8.2412N
# Time 0.022s | Total Thrust: 8.2602N
# Time 0.022s | Total Thrust: 8.2713N
# Time 0.022s | Total Thrust: 8.2787N
# Time 0.022s | Total Thrust: 8.2766N
# Time 0.022s | Total Thrust: 8.2712N
# Time 0.022s | Total Thrust: 8.2740N
# Time 0.022s | Total Thrust: 8.2766N
# Time 0.022s | Total Thrust: 8.2776N
# Time 0.022s | Total Thrust: 8.2676N
# Time 0.022s | Total Thrust: 8.2631N
# Time 0.022s | Total Thrust: 8.2648N
# Time 0.023s | Total Thrust: 8.2682N
# Time 0.023s | Total Thrust: 8.2702N
# Time 0.023s | Total Thrust: 8.2744N
# Time 0.023s | Total Thrust: 8.2815N
# Time 0.023s | Total Thrust: 8.2776N
# Time 0.023s | Total Thrust: 8.2784N
# Time 0.023s | Total Thrust: 8.2842N
# Time 0.023s | Total Thrust: 8.2902N
# Time 0.023s | Total Thrust: 8.2984N
# Time 0.023s | Total Thrust: 8.2992N
# Time 0.023s | Total Thrust: 8.2975N
# Time 0.023s | Total Thrust: 8.2848N
# Time 0.023s | Total Thrust: 8.2812N
# Time 0.023s | Total Thrust: 8.2742N
# Time 0.023s | Total Thrust: 8.2662N
# Time 0.023s | Total Thrust: 8.2660N
# Time 0.023s | Total Thrust: 8.2668N
# Time 0.023s | Total Thrust: 8.2621N
# Time 0.023s | Total Thrust: 8.2587N
# Time 0.023s | Total Thrust: 8.2513N
# Time 0.023s | Total Thrust: 8.2516N
# Time 0.023s | Total Thrust: 8.2617N
# Time 0.023s | Total Thrust: 8.2642N
# Time 0.023s | Total Thrust: 8.2700N
# Time 0.023s | Total Thrust: 8.2685N
# Time 0.023s | Total Thrust: 8.2589N
# Time 0.023s | Total Thrust: 8.2479N
# Time 0.023s | Total Thrust: 8.2463N
# Time 0.023s | Total Thrust: 8.2490N
# Time 0.023s | Total Thrust: 8.2508N
# Time 0.023s | Total Thrust: 8.2652N
# Time 0.023s | Total Thrust: 8.2754N
# Time 0.023s | Total Thrust: 8.2857N
# Time 0.023s | Total Thrust: 8.2897N
# Time 0.023s | Total Thrust: 8.2882N
# Time 0.024s | Total Thrust: 8.2805N
# Time 0.024s | Total Thrust: 8.2622N
# Time 0.024s | Total Thrust: 8.2616N
# Time 0.024s | Total Thrust: 8.2495N
# Time 0.024s | Total Thrust: 8.2497N
# Time 0.024s | Total Thrust: 8.2513N
# Time 0.024s | Total Thrust: 8.2604N
# Time 0.024s | Total Thrust: 8.2748N
# Time 0.024s | Total Thrust: 8.2835N
# Time 0.024s | Total Thrust: 8.2818N
# Time 0.024s | Total Thrust: 8.2763N
# Time 0.024s | Total Thrust: 8.2695N
# Time 0.024s | Total Thrust: 8.2719N
# Time 0.024s | Total Thrust: 8.2741N
# Time 0.024s | Total Thrust: 8.2858N
# Time 0.024s | Total Thrust: 8.2890N
# Time 0.024s | Total Thrust: 8.2864N
# Time 0.024s | Total Thrust: 8.2836N
# Time 0.024s | Total Thrust: 8.2831N
# Time 0.024s | Total Thrust: 8.2935N
# Time 0.024s | Total Thrust: 8.2927N
# Time 0.024s | Total Thrust: 8.2883N
# Time 0.024s | Total Thrust: 8.2887N
# Time 0.024s | Total Thrust: 8.2852N
# Time 0.024s | Total Thrust: 8.2876N
# Time 0.024s | Total Thrust: 8.2780N
# Time 0.024s | Total Thrust: 8.2747N
# Time 0.024s | Total Thrust: 8.2652N
# Time 0.024s | Total Thrust: 8.2614N
# Time 0.024s | Total Thrust: 8.2710N
# Time 0.024s | Total Thrust: 8.2765N
# Time 0.024s | Total Thrust: 8.2754N
# Time 0.024s | Total Thrust: 8.2791N
# Time 0.024s | Total Thrust: 8.2776N
# Time 0.024s | Total Thrust: 8.2745N
# Time 0.025s | Total Thrust: 8.2729N
# Time 0.025s | Total Thrust: 8.2751N
# Time 0.025s | Total Thrust: 8.2781N
# Time 0.025s | Total Thrust: 8.2756N
# Time 0.025s | Total Thrust: 8.2700N
# Time 0.025s | Total Thrust: 8.2623N
# Time 0.025s | Total Thrust: 8.2564N
# Time 0.025s | Total Thrust: 8.2564N
# Time 0.025s | Total Thrust: 8.2558N
# Time 0.025s | Total Thrust: 8.2646N
# Time 0.025s | Total Thrust: 8.2674N
# Time 0.025s | Total Thrust: 8.2712N
# Time 0.025s | Total Thrust: 8.2713N
# Time 0.025s | Total Thrust: 8.2731N
# Time 0.025s | Total Thrust: 8.2720N
# Time 0.025s | Total Thrust: 8.2728N
# Time 0.025s | Total Thrust: 8.2780N
# Time 0.025s | Total Thrust: 8.2753N
# Time 0.025s | Total Thrust: 8.2717N
# Time 0.025s | Total Thrust: 8.2660N
# Time 0.025s | Total Thrust: 8.2724N
# Time 0.025s | Total Thrust: 8.2763N
# Time 0.025s | Total Thrust: 8.2753N
# Time 0.025s | Total Thrust: 8.2768N
# Time 0.025s | Total Thrust: 8.2861N
# Time 0.025s | Total Thrust: 8.2896N
# Time 0.025s | Total Thrust: 8.2870N
# Time 0.025s | Total Thrust: 8.2911N
# Time 0.025s | Total Thrust: 8.2964N
# Time 0.025s | Total Thrust: 8.3021N
# Time 0.025s | Total Thrust: 8.3016N
# Time 0.025s | Total Thrust: 8.3041N
# Time 0.025s | Total Thrust: 8.3053N
# Time 0.025s | Total Thrust: 8.3100N
# Time 0.025s | Total Thrust: 8.3051N
# Time 0.026s | Total Thrust: 8.3073N
# Time 0.026s | Total Thrust: 8.3103N
# Time 0.026s | Total Thrust: 8.3215N
# Time 0.026s | Total Thrust: 8.3307N
# Time 0.026s | Total Thrust: 8.3349N
# Time 0.026s | Total Thrust: 8.3392N
# Time 0.026s | Total Thrust: 8.3363N
# Time 0.026s | Total Thrust: 8.3367N
# Time 0.026s | Total Thrust: 8.3291N
# Time 0.026s | Total Thrust: 8.3258N
# Time 0.026s | Total Thrust: 8.3236N
# Time 0.026s | Total Thrust: 8.3323N
# Time 0.026s | Total Thrust: 8.3350N
# Time 0.026s | Total Thrust: 8.3363N
# Time 0.026s | Total Thrust: 8.3301N
# Time 0.026s | Total Thrust: 8.3279N
# Time 0.026s | Total Thrust: 8.3206N
# Time 0.026s | Total Thrust: 8.3146N
# Time 0.026s | Total Thrust: 8.3125N
# Time 0.026s | Total Thrust: 8.3136N
# Time 0.026s | Total Thrust: 8.3110N
# Time 0.026s | Total Thrust: 8.3021N
# Time 0.026s | Total Thrust: 8.2981N
# Time 0.026s | Total Thrust: 8.2979N
# Time 0.026s | Total Thrust: 8.2941N
# Time 0.026s | Total Thrust: 8.2895N
# Time 0.026s | Total Thrust: 8.2877N
# Time 0.026s | Total Thrust: 8.2894N
# Time 0.026s | Total Thrust: 8.2878N
# Time 0.026s | Total Thrust: 8.2828N
# Time 0.026s | Total Thrust: 8.2864N
# Time 0.026s | Total Thrust: 8.2845N
# Time 0.026s | Total Thrust: 8.2768N
# Time 0.026s | Total Thrust: 8.2624N
# Time 0.026s | Total Thrust: 8.2524N
# Time 0.027s | Total Thrust: 8.2361N
# Time 0.027s | Total Thrust: 8.2032N
# Time 0.027s | Total Thrust: 8.1792N
# Time 0.027s | Total Thrust: 8.1813N
# Time 0.027s | Total Thrust: 8.1687N
# Time 0.027s | Total Thrust: 8.1678N
# Time 0.027s | Total Thrust: 8.1723N
# Time 0.027s | Total Thrust: 8.1740N
# Time 0.027s | Total Thrust: 8.1796N
# Time 0.027s | Total Thrust: 8.1803N
# Time 0.027s | Total Thrust: 8.1843N
# Time 0.027s | Total Thrust: 8.1914N
# Time 0.027s | Total Thrust: 8.1948N
# Time 0.027s | Total Thrust: 8.2023N
# Time 0.027s | Total Thrust: 8.2009N
# Time 0.027s | Total Thrust: 8.2034N
# Time 0.027s | Total Thrust: 8.1979N
# Time 0.027s | Total Thrust: 8.1867N
# Time 0.027s | Total Thrust: 8.1804N
# Time 0.027s | Total Thrust: 8.1817N
# Time 0.027s | Total Thrust: 8.1788N
# Time 0.027s | Total Thrust: 8.1815N
# Time 0.027s | Total Thrust: 8.1905N
# Time 0.027s | Total Thrust: 8.2010N
# Time 0.027s | Total Thrust: 8.2114N
# Time 0.027s | Total Thrust: 8.2189N
# Time 0.027s | Total Thrust: 8.2274N
# Time 0.027s | Total Thrust: 8.2331N
# Time 0.027s | Total Thrust: 8.2341N
# Time 0.027s | Total Thrust: 8.2409N
# Time 0.027s | Total Thrust: 8.2496N
# Time 0.027s | Total Thrust: 8.2504N
# Time 0.027s | Total Thrust: 8.2505N
# Time 0.027s | Total Thrust: 8.2439N
# Time 0.027s | Total Thrust: 8.2351N
# Time 0.028s | Total Thrust: 8.2281N
# Time 0.028s | Total Thrust: 8.2250N
# Time 0.028s | Total Thrust: 8.2244N
# Time 0.028s | Total Thrust: 8.2295N
# Time 0.028s | Total Thrust: 8.2226N
# Time 0.028s | Total Thrust: 8.2164N
# Time 0.028s | Total Thrust: 8.2243N
# Time 0.028s | Total Thrust: 8.2195N
# Time 0.028s | Total Thrust: 8.2181N
# Time 0.028s | Total Thrust: 8.2221N
# Time 0.028s | Total Thrust: 8.2250N
# Time 0.028s | Total Thrust: 8.2155N
# Time 0.028s | Total Thrust: 8.2224N
# Time 0.028s | Total Thrust: 8.2240N
# Time 0.028s | Total Thrust: 8.2289N
# Time 0.028s | Total Thrust: 8.2273N
# Time 0.028s | Total Thrust: 8.2424N
# Time 0.028s | Total Thrust: 8.2672N
# Time 0.028s | Total Thrust: 8.2703N
# Time 0.028s | Total Thrust: 8.2680N
# Time 0.028s | Total Thrust: 8.2625N
# Time 0.028s | Total Thrust: 8.2623N
# Time 0.028s | Total Thrust: 8.2544N
# Time 0.028s | Total Thrust: 8.2671N
# Time 0.028s | Total Thrust: 8.2708N
# Time 0.028s | Total Thrust: 8.2837N
# Time 0.028s | Total Thrust: 8.2792N
# Time 0.028s | Total Thrust: 8.2679N
# Time 0.028s | Total Thrust: 8.2654N
# Time 0.028s | Total Thrust: 8.2575N
# Time 0.028s | Total Thrust: 8.2468N
# Time 0.028s | Total Thrust: 8.2464N
# Time 0.028s | Total Thrust: 8.2430N
# Time 0.028s | Total Thrust: 8.2489N
# Time 0.028s | Total Thrust: 8.2597N
# Time 0.029s | Total Thrust: 8.2722N
# Time 0.029s | Total Thrust: 8.2778N
# Time 0.029s | Total Thrust: 8.2817N
# Time 0.029s | Total Thrust: 8.2786N
# Time 0.029s | Total Thrust: 8.2747N
# Time 0.029s | Total Thrust: 8.2658N
# Time 0.029s | Total Thrust: 8.2655N
# Time 0.029s | Total Thrust: 8.2688N
# Time 0.029s | Total Thrust: 8.2802N
# Time 0.029s | Total Thrust: 8.2878N
# Time 0.029s | Total Thrust: 8.2938N
# Time 0.029s | Total Thrust: 8.3058N
# Time 0.029s | Total Thrust: 8.3056N
# Time 0.029s | Total Thrust: 8.2959N
# Time 0.029s | Total Thrust: 8.2847N
# Time 0.029s | Total Thrust: 8.2744N
# Time 0.029s | Total Thrust: 8.2654N
# Time 0.029s | Total Thrust: 8.2450N
# Time 0.029s | Total Thrust: 8.2178N
# Time 0.029s | Total Thrust: 8.2087N
# Time 0.029s | Total Thrust: 8.2063N
# Time 0.029s | Total Thrust: 8.2069N
# Time 0.029s | Total Thrust: 8.2107N
# Time 0.029s | Total Thrust: 8.2076N
# Time 0.029s | Total Thrust: 8.2038N
# Time 0.029s | Total Thrust: 8.2070N
# Time 0.029s | Total Thrust: 8.2012N
# Time 0.029s | Total Thrust: 8.2015N
# Time 0.029s | Total Thrust: 8.2088N
# Time 0.029s | Total Thrust: 8.2136N
# Time 0.029s | Total Thrust: 8.2106N
# Time 0.029s | Total Thrust: 8.2066N
# Time 0.029s | Total Thrust: 8.2028N
# Time 0.029s | Total Thrust: 8.2039N
# Time 0.029s | Total Thrust: 8.2028N
# Time 0.030s | Total Thrust: 8.2088N
# Time 0.030s | Total Thrust: 8.2093N
# Time 0.030s | Total Thrust: 8.2107N
# Time 0.030s | Total Thrust: 8.2116N
# Time 0.030s | Total Thrust: 8.2095N
# Time 0.030s | Total Thrust: 8.2037N
# Time 0.030s | Total Thrust: 8.2035N
# Time 0.030s | Total Thrust: 8.2104N
# Time 0.030s | Total Thrust: 8.2209N
# Time 0.030s | Total Thrust: 8.2296N
# Time 0.030s | Total Thrust: 8.2351N
# Time 0.030s | Total Thrust: 8.2484N
# Time 0.030s | Total Thrust: 8.2579N
# Time 0.030s | Total Thrust: 8.2591N
# Time 0.030s | Total Thrust: 8.2631N
# Time 0.030s | Total Thrust: 8.2684N
# Time 0.030s | Total Thrust: 8.2592N
# Time 0.030s | Total Thrust: 8.2542N
# Time 0.030s | Total Thrust: 8.2557N
# Time 0.030s | Total Thrust: 8.2554N
# Time 0.030s | Total Thrust: 8.2659N
# Time 0.030s | Total Thrust: 8.2621N
# Time 0.030s | Total Thrust: 8.2595N
# Time 0.030s | Total Thrust: 8.2506N
# Time 0.030s | Total Thrust: 8.2428N
# Time 0.030s | Total Thrust: 8.2434N
# Time 0.030s | Total Thrust: 8.2332N
# Time 0.030s | Total Thrust: 8.2283N
# Time 0.030s | Total Thrust: 8.2114N
# Time 0.030s | Total Thrust: 8.1966N
# Time 0.030s | Total Thrust: 8.1819N
# Time 0.030s | Total Thrust: 8.1756N
# Time 0.030s | Total Thrust: 8.1753N
# Time 0.030s | Total Thrust: 8.1714N
# Time 0.030s | Total Thrust: 8.1763N
# Time 0.031s | Total Thrust: 8.1816N
# Time 0.031s | Total Thrust: 8.1861N
# Time 0.031s | Total Thrust: 8.1926N
# Time 0.031s | Total Thrust: 8.2060N
# Time 0.031s | Total Thrust: 8.2116N
# Time 0.031s | Total Thrust: 8.2115N
# Time 0.031s | Total Thrust: 8.2099N
# Time 0.031s | Total Thrust: 8.2083N
# Time 0.031s | Total Thrust: 8.2131N
# Time 0.031s | Total Thrust: 8.2099N
# Time 0.031s | Total Thrust: 8.1998N
# Time 0.031s | Total Thrust: 8.1915N
# Time 0.031s | Total Thrust: 8.1866N
# Time 0.031s | Total Thrust: 8.1778N
# Time 0.031s | Total Thrust: 8.1788N
# Time 0.031s | Total Thrust: 8.1810N
# Time 0.031s | Total Thrust: 8.1745N
# Time 0.031s | Total Thrust: 8.1699N
# Time 0.031s | Total Thrust: 8.1631N
# Time 0.031s | Total Thrust: 8.1625N
# Time 0.031s | Total Thrust: 8.1648N
# Time 0.031s | Total Thrust: 8.1683N
# Time 0.031s | Total Thrust: 8.1749N
# Time 0.031s | Total Thrust: 8.1744N
# Time 0.031s | Total Thrust: 8.1807N
# Time 0.031s | Total Thrust: 8.1855N
# Time 0.031s | Total Thrust: 8.2060N
# Time 0.031s | Total Thrust: 8.2255N
# Time 0.031s | Total Thrust: 8.2586N
# Time 0.031s | Total Thrust: 8.2736N
# Time 0.031s | Total Thrust: 8.2753N
# Time 0.031s | Total Thrust: 8.2674N
# Time 0.031s | Total Thrust: 8.2674N
# Time 0.031s | Total Thrust: 8.2666N
# Time 0.031s | Total Thrust: 8.2749N
# Time 0.032s | Total Thrust: 8.2843N
# Time 0.032s | Total Thrust: 8.2669N
# Time 0.032s | Total Thrust: 8.2635N
# Time 0.032s | Total Thrust: 8.2692N
# Time 0.032s | Total Thrust: 8.2742N
# Time 0.032s | Total Thrust: 8.2820N
# Time 0.032s | Total Thrust: 8.2863N
# Time 0.032s | Total Thrust: 8.2918N
# Time 0.032s | Total Thrust: 8.3044N
# Time 0.032s | Total Thrust: 8.3137N
# Time 0.032s | Total Thrust: 8.3207N
# Time 0.032s | Total Thrust: 8.3194N
# Time 0.032s | Total Thrust: 8.3204N
# Time 0.032s | Total Thrust: 8.3209N
# Time 0.032s | Total Thrust: 8.3116N
# Time 0.032s | Total Thrust: 8.2990N
# Time 0.032s | Total Thrust: 8.3027N
# Time 0.032s | Total Thrust: 8.3088N
# Time 0.032s | Total Thrust: 8.3112N
# Time 0.032s | Total Thrust: 8.3012N
# Time 0.032s | Total Thrust: 8.2979N
# Time 0.032s | Total Thrust: 8.2929N
# Time 0.032s | Total Thrust: 8.2939N
# Time 0.032s | Total Thrust: 8.2938N
# Time 0.032s | Total Thrust: 8.2969N
# Time 0.032s | Total Thrust: 8.2951N
# Time 0.032s | Total Thrust: 8.2962N
# Time 0.032s | Total Thrust: 8.2920N
# Time 0.032s | Total Thrust: 8.2859N
# Time 0.032s | Total Thrust: 8.2837N
# Time 0.032s | Total Thrust: 8.2804N
# Time 0.032s | Total Thrust: 8.2724N
# Time 0.032s | Total Thrust: 8.2800N
# Time 0.032s | Total Thrust: 8.2946N
# Time 0.032s | Total Thrust: 8.2940N
# Time 0.033s | Total Thrust: 8.2839N
# Time 0.033s | Total Thrust: 8.2759N
# Time 0.033s | Total Thrust: 8.2788N
# Time 0.033s | Total Thrust: 8.2791N
# Time 0.033s | Total Thrust: 8.2805N
# Time 0.033s | Total Thrust: 8.2717N
# Time 0.033s | Total Thrust: 8.2626N
# Time 0.033s | Total Thrust: 8.2484N
# Time 0.033s | Total Thrust: 8.2428N
# Time 0.033s | Total Thrust: 8.2396N
# Time 0.033s | Total Thrust: 8.2389N
# Time 0.033s | Total Thrust: 8.2292N
# Time 0.033s | Total Thrust: 8.2250N
# Time 0.033s | Total Thrust: 8.2251N
# Time 0.033s | Total Thrust: 8.2307N
# Time 0.033s | Total Thrust: 8.2373N
# Time 0.033s | Total Thrust: 8.2464N
# Time 0.033s | Total Thrust: 8.2570N
# Time 0.033s | Total Thrust: 8.2699N
# Time 0.033s | Total Thrust: 8.2785N
# Time 0.033s | Total Thrust: 8.2792N
# Time 0.033s | Total Thrust: 8.2996N
# Time 0.033s | Total Thrust: 8.3177N
# Time 0.033s | Total Thrust: 8.3212N
# Time 0.033s | Total Thrust: 8.3137N
# Time 0.033s | Total Thrust: 8.3105N
# Time 0.033s | Total Thrust: 8.3062N
# Time 0.033s | Total Thrust: 8.3036N
# Time 0.033s | Total Thrust: 8.3093N
# Time 0.033s | Total Thrust: 8.3221N
# Time 0.033s | Total Thrust: 8.3324N
# Time 0.033s | Total Thrust: 8.3395N
# Time 0.033s | Total Thrust: 8.3391N
# Time 0.033s | Total Thrust: 8.3361N
# Time 0.033s | Total Thrust: 8.3430N
# Time 0.034s | Total Thrust: 8.3487N
# Time 0.034s | Total Thrust: 8.3509N
# Time 0.034s | Total Thrust: 8.3438N
# Time 0.034s | Total Thrust: 8.3259N
# Time 0.034s | Total Thrust: 8.2949N
# Time 0.034s | Total Thrust: 8.2904N
# Time 0.034s | Total Thrust: 8.2819N
# Time 0.034s | Total Thrust: 8.2693N
# Time 0.034s | Total Thrust: 8.2680N
# Time 0.034s | Total Thrust: 8.2667N
# Time 0.034s | Total Thrust: 8.2672N
# Time 0.034s | Total Thrust: 8.2728N
# Time 0.034s | Total Thrust: 8.2859N
# Time 0.034s | Total Thrust: 8.2850N
# Time 0.034s | Total Thrust: 8.2795N
# Time 0.034s | Total Thrust: 8.2673N
# Time 0.034s | Total Thrust: 8.2644N
# Time 0.034s | Total Thrust: 8.2642N
# Time 0.034s | Total Thrust: 8.2629N
# Time 0.034s | Total Thrust: 8.2611N
# Time 0.034s | Total Thrust: 8.2560N
# Time 0.034s | Total Thrust: 8.2678N
# Time 0.034s | Total Thrust: 8.2769N
# Time 0.034s | Total Thrust: 8.2848N
# Time 0.034s | Total Thrust: 8.2847N
# Time 0.034s | Total Thrust: 8.2765N
# Time 0.034s | Total Thrust: 8.2706N
# Time 0.034s | Total Thrust: 8.2746N
# Time 0.034s | Total Thrust: 8.2750N
# Time 0.034s | Total Thrust: 8.2724N
# Time 0.034s | Total Thrust: 8.2706N
# Time 0.034s | Total Thrust: 8.2754N
# Time 0.034s | Total Thrust: 8.2746N
# Time 0.034s | Total Thrust: 8.2766N
# Time 0.034s | Total Thrust: 8.2838N
# Time 0.035s | Total Thrust: 8.2903N
# Time 0.035s | Total Thrust: 8.2953N
# Time 0.035s | Total Thrust: 8.2941N
# Time 0.035s | Total Thrust: 8.2903N
# Time 0.035s | Total Thrust: 8.2823N
# Time 0.035s | Total Thrust: 8.2763N
# Time 0.035s | Total Thrust: 8.2656N
# Time 0.035s | Total Thrust: 8.2596N
# Time 0.035s | Total Thrust: 8.2611N
# Time 0.035s | Total Thrust: 8.2654N
# Time 0.035s | Total Thrust: 8.2705N
# Time 0.035s | Total Thrust: 8.2681N
# Time 0.035s | Total Thrust: 8.2751N
# Time 0.035s | Total Thrust: 8.2775N
# Time 0.035s | Total Thrust: 8.2707N
# Time 0.035s | Total Thrust: 8.2598N
# Time 0.035s | Total Thrust: 8.2564N
# Time 0.035s | Total Thrust: 8.2533N
# Time 0.035s | Total Thrust: 8.2624N
# Time 0.035s | Total Thrust: 8.2475N
# Time 0.035s | Total Thrust: 8.2372N
# Time 0.035s | Total Thrust: 8.2396N
# Time 0.035s | Total Thrust: 8.2381N
# Time 0.035s | Total Thrust: 8.2469N
# Time 0.035s | Total Thrust: 8.2467N
# Time 0.035s | Total Thrust: 8.2548N
# Time 0.035s | Total Thrust: 8.2535N
# Time 0.035s | Total Thrust: 8.2476N
# Time 0.035s | Total Thrust: 8.2432N
# Time 0.035s | Total Thrust: 8.2355N
# Time 0.035s | Total Thrust: 8.2412N
# Time 0.035s | Total Thrust: 8.2419N
# Time 0.035s | Total Thrust: 8.2473N
# Time 0.035s | Total Thrust: 8.2416N
# Time 0.035s | Total Thrust: 8.2420N
# Time 0.036s | Total Thrust: 8.2388N
# Time 0.036s | Total Thrust: 8.2367N
# Time 0.036s | Total Thrust: 8.2282N
# Time 0.036s | Total Thrust: 8.2255N
# Time 0.036s | Total Thrust: 8.2237N
# Time 0.036s | Total Thrust: 8.2156N
# Time 0.036s | Total Thrust: 8.2047N
# Time 0.036s | Total Thrust: 8.2080N
# Time 0.036s | Total Thrust: 8.2223N
# Time 0.036s | Total Thrust: 8.2255N
# Time 0.036s | Total Thrust: 8.2268N
# Time 0.036s | Total Thrust: 8.2323N
# Time 0.036s | Total Thrust: 8.2336N
# Time 0.036s | Total Thrust: 8.2363N
# Time 0.036s | Total Thrust: 8.2498N
# Time 0.036s | Total Thrust: 8.2554N
# Time 0.036s | Total Thrust: 8.2591N
# Time 0.036s | Total Thrust: 8.2510N
# Time 0.036s | Total Thrust: 8.2468N
# Time 0.036s | Total Thrust: 8.2531N
# Time 0.036s | Total Thrust: 8.2608N
# Time 0.036s | Total Thrust: 8.2685N
# Time 0.036s | Total Thrust: 8.2663N
# Time 0.036s | Total Thrust: 8.2651N
# Time 0.036s | Total Thrust: 8.2725N
# Time 0.036s | Total Thrust: 8.2817N
# Time 0.036s | Total Thrust: 8.2749N
# Time 0.036s | Total Thrust: 8.2647N
# Time 0.036s | Total Thrust: 8.2553N
# Time 0.036s | Total Thrust: 8.2527N
# Time 0.036s | Total Thrust: 8.2565N
# Time 0.036s | Total Thrust: 8.2587N
# Time 0.036s | Total Thrust: 8.2605N
# Time 0.036s | Total Thrust: 8.2695N
# Time 0.036s | Total Thrust: 8.2708N
# Time 0.037s | Total Thrust: 8.2694N
# Time 0.037s | Total Thrust: 8.2621N
# Time 0.037s | Total Thrust: 8.2691N
# Time 0.037s | Total Thrust: 8.2640N
# Time 0.037s | Total Thrust: 8.2728N
# Time 0.037s | Total Thrust: 8.2804N
# Time 0.037s | Total Thrust: 8.2864N
# Time 0.037s | Total Thrust: 8.2880N
# Time 0.037s | Total Thrust: 8.2913N
# Time 0.037s | Total Thrust: 8.2893N
# Time 0.037s | Total Thrust: 8.2875N
# Time 0.037s | Total Thrust: 8.2801N
# Time 0.037s | Total Thrust: 8.2693N
# Time 0.037s | Total Thrust: 8.2593N
# Time 0.037s | Total Thrust: 8.2590N
# Time 0.037s | Total Thrust: 8.2515N
# Time 0.037s | Total Thrust: 8.2515N
# Time 0.037s | Total Thrust: 8.2472N
# Time 0.037s | Total Thrust: 8.2456N
# Time 0.037s | Total Thrust: 8.2468N
# Time 0.037s | Total Thrust: 8.2547N
# Time 0.037s | Total Thrust: 8.2607N
# Time 0.037s | Total Thrust: 8.2673N
# Time 0.037s | Total Thrust: 8.2681N
# Time 0.037s | Total Thrust: 8.2677N
# Time 0.037s | Total Thrust: 8.2618N
# Time 0.037s | Total Thrust: 8.2626N
# Time 0.037s | Total Thrust: 8.2612N
# Time 0.037s | Total Thrust: 8.2478N
# Time 0.037s | Total Thrust: 8.2412N
# Time 0.037s | Total Thrust: 8.2405N
# Time 0.037s | Total Thrust: 8.2427N
# Time 0.037s | Total Thrust: 8.2370N
# Time 0.037s | Total Thrust: 8.2384N
# Time 0.037s | Total Thrust: 8.2349N
# Time 0.038s | Total Thrust: 8.2350N
# Time 0.038s | Total Thrust: 8.2418N
# Time 0.038s | Total Thrust: 8.2489N
# Time 0.038s | Total Thrust: 8.2583N
# Time 0.038s | Total Thrust: 8.2546N
# Time 0.038s | Total Thrust: 8.2506N
# Time 0.038s | Total Thrust: 8.2482N
# Time 0.038s | Total Thrust: 8.2454N
# Time 0.038s | Total Thrust: 8.2389N
# Time 0.038s | Total Thrust: 8.2403N
# Time 0.038s | Total Thrust: 8.2380N
# Time 0.038s | Total Thrust: 8.2369N
# Time 0.038s | Total Thrust: 8.2367N
# Time 0.038s | Total Thrust: 8.2344N
# Time 0.038s | Total Thrust: 8.2262N
# Time 0.038s | Total Thrust: 8.2137N
# Time 0.038s | Total Thrust: 8.2053N
# Time 0.038s | Total Thrust: 8.2030N
# Time 0.038s | Total Thrust: 8.2024N
# Time 0.038s | Total Thrust: 8.1993N
# ...
# Time 0.416s | Total Thrust: 8.2526N
# Time 0.416s | Total Thrust: 8.2576N
# Time 0.416s | Total Thrust: 8.2583N
# Time 0.416s | Total Thrust: 8.2624N
# Time 0.416s | Total Thrust: 8.2576N
# Time 0.416s | Total Thrust: 8.2552N
# Time 0.416s | Total Thrust: 8.2524N
# Time 0.416s | Total Thrust: 8.2501N
# Time 0.416s | Total Thrust: 8.2398N
# Time 0.416s | Total Thrust: 8.2334N
# Time 0.416s | Total Thrust: 8.2351N
# Time 0.416s | Total Thrust: 8.2369N
# Time 0.416s | Total Thrust: 8.2352N
# Time 0.416s | Total Thrust: 8.2372N
# Time 0.416s | Total Thrust: 8.2346N
# Time 0.416s | Total Thrust: 8.2349N
# Time 0.416s | Total Thrust: 8.2319N
# Time 0.416s | Total Thrust: 8.2286N
# Time 0.416s | Total Thrust: 8.2330N
# Time 0.416s | Total Thrust: 8.2388N
# Time 0.416s | Total Thrust: 8.2618N
# Time 0.416s | Total Thrust: 8.2786N
# Time 0.417s | Total Thrust: 8.2687N
# Time 0.417s | Total Thrust: 8.2722N
# Time 0.417s | Total Thrust: 8.2762N
# Time 0.417s | Total Thrust: 8.2761N
# Time 0.417s | Total Thrust: 8.2738N
# Time 0.417s | Total Thrust: 8.2749N
# Time 0.417s | Total Thrust: 8.2840N
# Time 0.417s | Total Thrust: 8.2894N
# Time 0.417s | Total Thrust: 8.2844N
# Time 0.417s | Total Thrust: 8.2800N
# Time 0.417s | Total Thrust: 8.2742N
# Time 0.417s | Total Thrust: 8.2753N
# Time 0.417s | Total Thrust: 8.2700N
# Time 0.417s | Total Thrust: 8.2599N
# Time 0.417s | Total Thrust: 8.2572N
# Time 0.417s | Total Thrust: 8.2535N
# Time 0.417s | Total Thrust: 8.2553N
# Time 0.417s | Total Thrust: 8.2594N
# Time 0.417s | Total Thrust: 8.2669N
# Time 0.417s | Total Thrust: 8.2741N
# Time 0.417s | Total Thrust: 8.2773N
# Time 0.417s | Total Thrust: 8.2778N
# Time 0.417s | Total Thrust: 8.2757N
# Time 0.417s | Total Thrust: 8.2766N
# Time 0.417s | Total Thrust: 8.2709N
# Time 0.417s | Total Thrust: 8.2625N
# Time 0.417s | Total Thrust: 8.2618N
# Time 0.417s | Total Thrust: 8.2690N
# Time 0.417s | Total Thrust: 8.2757N
# Time 0.417s | Total Thrust: 8.2791N
# Time 0.417s | Total Thrust: 8.2844N
# Time 0.417s | Total Thrust: 8.2873N
# Time 0.417s | Total Thrust: 8.2892N
# Time 0.417s | Total Thrust: 8.2927N
# Time 0.417s | Total Thrust: 8.2949N
# Time 0.418s | Total Thrust: 8.2899N
# Time 0.418s | Total Thrust: 8.2886N
# Time 0.418s | Total Thrust: 8.2905N
# Time 0.418s | Total Thrust: 8.2953N
# Time 0.418s | Total Thrust: 8.2979N
# Time 0.418s | Total Thrust: 8.2995N
# Time 0.418s | Total Thrust: 8.3034N
# Time 0.418s | Total Thrust: 8.3032N
# Time 0.418s | Total Thrust: 8.3018N
# Time 0.418s | Total Thrust: 8.3019N
# Time 0.418s | Total Thrust: 8.2996N
# Time 0.418s | Total Thrust: 8.3051N
# Time 0.418s | Total Thrust: 8.3071N
# Time 0.418s | Total Thrust: 8.3026N
# Time 0.418s | Total Thrust: 8.3023N
# Time 0.418s | Total Thrust: 8.3019N
# Time 0.418s | Total Thrust: 8.3058N
# Time 0.418s | Total Thrust: 8.2970N
# Time 0.418s | Total Thrust: 8.2906N
# Time 0.418s | Total Thrust: 8.2838N
# Time 0.418s | Total Thrust: 8.2827N
# Time 0.418s | Total Thrust: 8.2872N
# Time 0.418s | Total Thrust: 8.2958N
# Time 0.418s | Total Thrust: 8.2982N
# Time 0.418s | Total Thrust: 8.2992N
# Time 0.418s | Total Thrust: 8.2966N
# Time 0.418s | Total Thrust: 8.2943N
# Time 0.418s | Total Thrust: 8.2962N
# Time 0.418s | Total Thrust: 8.2929N
# Time 0.418s | Total Thrust: 8.3003N
# Time 0.418s | Total Thrust: 8.2956N
# Time 0.418s | Total Thrust: 8.2993N
# Time 0.418s | Total Thrust: 8.3086N
# Time 0.418s | Total Thrust: 8.3112N
# Time 0.418s | Total Thrust: 8.3156N
# Time 0.419s | Total Thrust: 8.3242N
# Time 0.419s | Total Thrust: 8.3291N
# Time 0.419s | Total Thrust: 8.3297N
# Time 0.419s | Total Thrust: 8.3231N
# Time 0.419s | Total Thrust: 8.3172N
# Time 0.419s | Total Thrust: 8.3161N
# Time 0.419s | Total Thrust: 8.3106N
# Time 0.419s | Total Thrust: 8.3004N
# Time 0.419s | Total Thrust: 8.2947N
# Time 0.419s | Total Thrust: 8.2898N
# Time 0.419s | Total Thrust: 8.2873N
# Time 0.419s | Total Thrust: 8.2844N
# Time 0.419s | Total Thrust: 8.2814N
# Time 0.419s | Total Thrust: 8.2786N
# Time 0.419s | Total Thrust: 8.2758N
# Time 0.419s | Total Thrust: 8.2772N
# Time 0.419s | Total Thrust: 8.2760N
# Time 0.419s | Total Thrust: 8.2715N
# Time 0.419s | Total Thrust: 8.2641N
# Time 0.419s | Total Thrust: 8.2575N
# Time 0.419s | Total Thrust: 8.2480N
# Time 0.419s | Total Thrust: 8.2525N
# Time 0.419s | Total Thrust: 8.2494N
# Time 0.419s | Total Thrust: 8.2454N
# Time 0.419s | Total Thrust: 8.2455N
# Time 0.419s | Total Thrust: 8.2516N
# Time 0.419s | Total Thrust: 8.2611N
# Time 0.419s | Total Thrust: 8.2661N
# Time 0.419s | Total Thrust: 8.2719N
# Time 0.419s | Total Thrust: 8.2731N
# Time 0.419s | Total Thrust: 8.2808N
# Time 0.419s | Total Thrust: 8.2824N
# Time 0.419s | Total Thrust: 8.2838N
# Time 0.419s | Total Thrust: 8.2837N
# Time 0.419s | Total Thrust: 8.2789N
# Time 0.420s | Total Thrust: 8.2757N
# Time 0.420s | Total Thrust: 8.2729N
# Time 0.420s | Total Thrust: 8.2663N
# Time 0.420s | Total Thrust: 8.2569N
# Time 0.420s | Total Thrust: 8.2529N
# Time 0.420s | Total Thrust: 8.2516N
# Time 0.420s | Total Thrust: 8.2518N
# Time 0.420s | Total Thrust: 8.2522N
# Time 0.420s | Total Thrust: 8.2558N
# Time 0.420s | Total Thrust: 8.2616N
# Time 0.420s | Total Thrust: 8.2605N
# Time 0.420s | Total Thrust: 8.2616N
# Time 0.420s | Total Thrust: 8.2577N
# Time 0.420s | Total Thrust: 8.2423N
# Time 0.420s | Total Thrust: 8.2289N
# Time 0.420s | Total Thrust: 8.2300N
# Time 0.420s | Total Thrust: 8.2238N
# Time 0.420s | Total Thrust: 8.2223N
# Time 0.420s | Total Thrust: 8.2228N
# Time 0.420s | Total Thrust: 8.2252N
# Time 0.420s | Total Thrust: 8.2219N
# Time 0.420s | Total Thrust: 8.2267N
# Time 0.420s | Total Thrust: 8.2337N
# Time 0.420s | Total Thrust: 8.2326N
# Time 0.420s | Total Thrust: 8.2321N
# Time 0.420s | Total Thrust: 8.2366N
# Time 0.420s | Total Thrust: 8.2439N
# Time 0.420s | Total Thrust: 8.2582N
# Time 0.420s | Total Thrust: 8.2535N
# Time 0.420s | Total Thrust: 8.2598N
# Time 0.420s | Total Thrust: 8.2581N
# Time 0.420s | Total Thrust: 8.2600N
# Time 0.420s | Total Thrust: 8.2456N
# Time 0.420s | Total Thrust: 8.2479N
# Time 0.420s | Total Thrust: 8.2461N
# Time 0.421s | Total Thrust: 8.2534N
# Time 0.421s | Total Thrust: 8.2589N
# Time 0.421s | Total Thrust: 8.2613N
# Time 0.421s | Total Thrust: 8.2577N
# Time 0.421s | Total Thrust: 8.2539N
# Time 0.421s | Total Thrust: 8.2420N
# Time 0.421s | Total Thrust: 8.2388N
# Time 0.421s | Total Thrust: 8.2671N
# Time 0.421s | Total Thrust: 8.2736N
# Time 0.421s | Total Thrust: 8.2719N
# Time 0.421s | Total Thrust: 8.2680N
# Time 0.421s | Total Thrust: 8.2638N
# Time 0.421s | Total Thrust: 8.2581N
# Time 0.421s | Total Thrust: 8.2545N
# Time 0.421s | Total Thrust: 8.2564N
# Time 0.421s | Total Thrust: 8.2582N
# Time 0.421s | Total Thrust: 8.2688N
# Time 0.421s | Total Thrust: 8.2653N
# Time 0.421s | Total Thrust: 8.2658N
# Time 0.421s | Total Thrust: 8.2676N
# Time 0.421s | Total Thrust: 8.2667N
# Time 0.421s | Total Thrust: 8.2612N
# Time 0.421s | Total Thrust: 8.2551N
# Time 0.421s | Total Thrust: 8.2571N
# Time 0.421s | Total Thrust: 8.2591N
# Time 0.421s | Total Thrust: 8.2640N
# Time 0.421s | Total Thrust: 8.2616N
# Time 0.421s | Total Thrust: 8.2512N
# Time 0.421s | Total Thrust: 8.2468N
# Time 0.421s | Total Thrust: 8.2495N
# Time 0.421s | Total Thrust: 8.2509N
# Time 0.421s | Total Thrust: 8.2520N
# Time 0.421s | Total Thrust: 8.2541N
# Time 0.421s | Total Thrust: 8.2678N
# Time 0.421s | Total Thrust: 8.2751N
# Time 0.422s | Total Thrust: 8.2794N
# Time 0.422s | Total Thrust: 8.2864N
# Time 0.422s | Total Thrust: 8.2959N
# Time 0.422s | Total Thrust: 8.3051N
# Time 0.422s | Total Thrust: 8.2997N
# Time 0.422s | Total Thrust: 8.2948N
# Time 0.422s | Total Thrust: 8.2977N
# Time 0.422s | Total Thrust: 8.3052N
# Time 0.422s | Total Thrust: 8.3116N
# Time 0.422s | Total Thrust: 8.3190N
# Time 0.422s | Total Thrust: 8.3185N
# Time 0.422s | Total Thrust: 8.3353N
# Time 0.422s | Total Thrust: 8.3108N
# Time 0.422s | Total Thrust: 8.3401N
# Time 0.422s | Total Thrust: 8.3048N
# Time 0.422s | Total Thrust: 8.3368N
# Time 0.422s | Total Thrust: 8.3043N
# Time 0.422s | Total Thrust: 8.3399N
# Time 0.422s | Total Thrust: 8.3059N
# Time 0.422s | Total Thrust: 8.3461N
# Time 0.422s | Total Thrust: 8.3065N
# Time 0.422s | Total Thrust: 8.3430N
# Time 0.422s | Total Thrust: 8.3083N
# Time 0.422s | Total Thrust: 8.3421N
# Time 0.422s | Total Thrust: 8.3047N
# Time 0.422s | Total Thrust: 8.3394N
# Time 0.422s | Total Thrust: 8.3053N
# Time 0.422s | Total Thrust: 8.3483N
# Time 0.422s | Total Thrust: 8.3066N
# Time 0.422s | Total Thrust: 8.3551N
# Time 0.422s | Total Thrust: 8.3014N
# Time 0.422s | Total Thrust: 8.3547N
# Time 0.422s | Total Thrust: 8.3045N
# Time 0.422s | Total Thrust: 8.3542N
# Time 0.422s | Total Thrust: 8.3014N
# Time 0.423s | Total Thrust: 8.3421N
# Time 0.423s | Total Thrust: 8.2972N
# Time 0.423s | Total Thrust: 8.3277N
# Time 0.423s | Total Thrust: 8.2925N
# Time 0.423s | Total Thrust: 8.3113N
# Time 0.423s | Total Thrust: 8.2876N
# Time 0.423s | Total Thrust: 8.2883N
# Time 0.423s | Total Thrust: 8.2644N
# Time 0.423s | Total Thrust: 8.2654N
# Time 0.423s | Total Thrust: 8.2645N
# Time 0.423s | Total Thrust: 8.2627N
# Time 0.423s | Total Thrust: 8.2640N
# Time 0.423s | Total Thrust: 8.2701N
# Time 0.423s | Total Thrust: 8.2707N
# Time 0.423s | Total Thrust: 8.2715N
# Time 0.423s | Total Thrust: 8.2700N
# Time 0.423s | Total Thrust: 8.2632N
# Time 0.423s | Total Thrust: 8.2639N
# Time 0.423s | Total Thrust: 8.2653N
# Time 0.423s | Total Thrust: 8.2760N
# Time 0.423s | Total Thrust: 8.2812N
# Time 0.423s | Total Thrust: 8.2812N
# Time 0.423s | Total Thrust: 8.2839N
# Time 0.423s | Total Thrust: 8.2918N
# Time 0.423s | Total Thrust: 8.2911N
# Time 0.423s | Total Thrust: 8.2857N
# Time 0.423s | Total Thrust: 8.2846N
# Time 0.423s | Total Thrust: 8.2795N
# Time 0.423s | Total Thrust: 8.2536N
# Time 0.423s | Total Thrust: 8.2208N
# Time 0.423s | Total Thrust: 8.2056N
# Time 0.423s | Total Thrust: 8.2011N
# Time 0.423s | Total Thrust: 8.2097N
# Time 0.423s | Total Thrust: 8.2200N
# Time 0.423s | Total Thrust: 8.2253N
# Time 0.424s | Total Thrust: 8.2290N
# Time 0.424s | Total Thrust: 8.2302N
# Time 0.424s | Total Thrust: 8.2319N
# Time 0.424s | Total Thrust: 8.2330N
# Time 0.424s | Total Thrust: 8.2354N
# Time 0.424s | Total Thrust: 8.2333N
# Time 0.424s | Total Thrust: 8.2364N
# Time 0.424s | Total Thrust: 8.2324N
# Time 0.424s | Total Thrust: 8.2307N
# Time 0.424s | Total Thrust: 8.2255N
# Time 0.424s | Total Thrust: 8.2284N
# Time 0.424s | Total Thrust: 8.2332N
# Time 0.424s | Total Thrust: 8.2363N
# Time 0.424s | Total Thrust: 8.2250N
# Time 0.424s | Total Thrust: 8.2237N
# Time 0.424s | Total Thrust: 8.2219N
# Time 0.424s | Total Thrust: 8.2187N
# Time 0.424s | Total Thrust: 8.2263N
# Time 0.424s | Total Thrust: 8.2323N
# Time 0.424s | Total Thrust: 8.2464N
# Time 0.424s | Total Thrust: 8.2462N
# Time 0.424s | Total Thrust: 8.2326N
# Time 0.424s | Total Thrust: 8.2186N
# Time 0.424s | Total Thrust: 8.2055N
# Time 0.424s | Total Thrust: 8.1981N
# Time 0.424s | Total Thrust: 8.1869N
# Time 0.424s | Total Thrust: 8.1820N
# Time 0.424s | Total Thrust: 8.1888N
# Time 0.424s | Total Thrust: 8.1888N
# Time 0.424s | Total Thrust: 8.1881N
# Time 0.424s | Total Thrust: 8.1769N
# Time 0.424s | Total Thrust: 8.1864N
# Time 0.424s | Total Thrust: 8.1931N
# Time 0.424s | Total Thrust: 8.1970N
# Time 0.424s | Total Thrust: 8.2118N
# Time 0.425s | Total Thrust: 8.2257N
# Time 0.425s | Total Thrust: 8.2408N
# Time 0.425s | Total Thrust: 8.2392N
# Time 0.425s | Total Thrust: 8.2364N
# Time 0.425s | Total Thrust: 8.2289N
# Time 0.425s | Total Thrust: 8.2300N
# Time 0.425s | Total Thrust: 8.2322N
# Time 0.425s | Total Thrust: 8.2356N
# Time 0.425s | Total Thrust: 8.2324N
# Time 0.425s | Total Thrust: 8.2292N
# Time 0.425s | Total Thrust: 8.2293N
# Time 0.425s | Total Thrust: 8.2278N
# Time 0.425s | Total Thrust: 8.2292N
# Time 0.425s | Total Thrust: 8.2238N
# Time 0.425s | Total Thrust: 8.2246N
# Time 0.425s | Total Thrust: 8.2268N
# Time 0.425s | Total Thrust: 8.2345N
# Time 0.425s | Total Thrust: 8.2379N
# Time 0.425s | Total Thrust: 8.2440N
# Time 0.425s | Total Thrust: 8.2494N
# Time 0.425s | Total Thrust: 8.2479N
# Time 0.425s | Total Thrust: 8.2414N
# Time 0.425s | Total Thrust: 8.2425N
# Time 0.425s | Total Thrust: 8.2347N
# Time 0.425s | Total Thrust: 8.2285N
# Time 0.425s | Total Thrust: 8.2253N
# Time 0.425s | Total Thrust: 8.2170N
# Time 0.425s | Total Thrust: 8.2148N
# Time 0.425s | Total Thrust: 8.2112N
# Time 0.425s | Total Thrust: 8.2129N
# Time 0.425s | Total Thrust: 8.2168N
# Time 0.425s | Total Thrust: 8.2157N
# Time 0.425s | Total Thrust: 8.2179N
# Time 0.425s | Total Thrust: 8.2265N
# Time 0.425s | Total Thrust: 8.2324N
# Time 0.426s | Total Thrust: 8.2426N
# Time 0.426s | Total Thrust: 8.2434N
# Time 0.426s | Total Thrust: 8.2477N
# Time 0.426s | Total Thrust: 8.2518N
# Time 0.426s | Total Thrust: 8.2564N
# Time 0.426s | Total Thrust: 8.2548N
# Time 0.426s | Total Thrust: 8.2563N
# Time 0.426s | Total Thrust: 8.2584N
# Time 0.426s | Total Thrust: 8.2562N
# Time 0.426s | Total Thrust: 8.2518N
# Time 0.426s | Total Thrust: 8.2531N
# Time 0.426s | Total Thrust: 8.2643N
# Time 0.426s | Total Thrust: 8.2702N
# Time 0.426s | Total Thrust: 8.2713N
# Time 0.426s | Total Thrust: 8.2682N
# Time 0.426s | Total Thrust: 8.2658N
# Time 0.426s | Total Thrust: 8.2609N
# Time 0.426s | Total Thrust: 8.2564N
# Time 0.426s | Total Thrust: 8.2587N
# Time 0.426s | Total Thrust: 8.2670N
# Time 0.426s | Total Thrust: 8.2749N
# Time 0.426s | Total Thrust: 8.2708N
# Time 0.426s | Total Thrust: 8.2663N
# Time 0.426s | Total Thrust: 8.2689N
# Time 0.426s | Total Thrust: 8.2700N
# Time 0.426s | Total Thrust: 8.2691N
# Time 0.426s | Total Thrust: 8.2719N
# Time 0.426s | Total Thrust: 8.2615N
# Time 0.426s | Total Thrust: 8.2534N
# Time 0.426s | Total Thrust: 8.2467N
# Time 0.426s | Total Thrust: 8.2482N
# Time 0.426s | Total Thrust: 8.2436N
# Time 0.426s | Total Thrust: 8.2443N
# Time 0.426s | Total Thrust: 8.2419N
# Time 0.426s | Total Thrust: 8.2433N
# Time 0.427s | Total Thrust: 8.2452N
# Time 0.427s | Total Thrust: 8.2516N
# Time 0.427s | Total Thrust: 8.2587N
# Time 0.427s | Total Thrust: 8.2578N
# Time 0.427s | Total Thrust: 8.2659N
# Time 0.427s | Total Thrust: 8.2593N
# Time 0.427s | Total Thrust: 8.2665N
# Time 0.427s | Total Thrust: 8.2579N
# Time 0.427s | Total Thrust: 8.2635N
# Time 0.427s | Total Thrust: 8.2295N
# Time 0.427s | Total Thrust: 8.2424N
# Time 0.427s | Total Thrust: 8.2179N
# Time 0.427s | Total Thrust: 8.2182N
# Time 0.427s | Total Thrust: 8.2009N
# Time 0.427s | Total Thrust: 8.2035N
# Time 0.427s | Total Thrust: 8.2029N
# Time 0.427s | Total Thrust: 8.2096N
# Time 0.427s | Total Thrust: 8.2125N
# Time 0.427s | Total Thrust: 8.2164N
# Time 0.427s | Total Thrust: 8.2161N
# Time 0.427s | Total Thrust: 8.2177N
# Time 0.427s | Total Thrust: 8.2161N
# Time 0.427s | Total Thrust: 8.2178N
# Time 0.427s | Total Thrust: 8.2183N
# Time 0.427s | Total Thrust: 8.2200N
# Time 0.427s | Total Thrust: 8.2282N
# Time 0.427s | Total Thrust: 8.2281N
# Time 0.427s | Total Thrust: 8.2212N
# Time 0.427s | Total Thrust: 8.2059N
# Time 0.427s | Total Thrust: 8.2011N
# Time 0.427s | Total Thrust: 8.2000N
# Time 0.427s | Total Thrust: 8.1985N
# Time 0.427s | Total Thrust: 8.2018N
# Time 0.427s | Total Thrust: 8.2025N
# Time 0.427s | Total Thrust: 8.1982N
# Time 0.428s | Total Thrust: 8.1894N
# Time 0.428s | Total Thrust: 8.1846N
# Time 0.428s | Total Thrust: 8.1879N
# Time 0.428s | Total Thrust: 8.1881N
# Time 0.428s | Total Thrust: 8.1869N
# Time 0.428s | Total Thrust: 8.1878N
# Time 0.428s | Total Thrust: 8.1889N
# Time 0.428s | Total Thrust: 8.2027N
# Time 0.428s | Total Thrust: 8.2158N
# Time 0.428s | Total Thrust: 8.2449N
# Time 0.428s | Total Thrust: 8.2498N
# Time 0.428s | Total Thrust: 8.2365N
# Time 0.428s | Total Thrust: 8.2370N
# Time 0.428s | Total Thrust: 8.2432N
# Time 0.428s | Total Thrust: 8.2472N
# Time 0.428s | Total Thrust: 8.2580N
# Time 0.428s | Total Thrust: 8.2579N
# Time 0.428s | Total Thrust: 8.2708N
# Time 0.428s | Total Thrust: 8.2810N
# Time 0.428s | Total Thrust: 8.2768N
# Time 0.428s | Total Thrust: 8.2734N
# Time 0.428s | Total Thrust: 8.2830N
# Time 0.428s | Total Thrust: 8.2786N
# Time 0.428s | Total Thrust: 8.2758N
# Time 0.428s | Total Thrust: 8.2700N
# Time 0.428s | Total Thrust: 8.2609N
# Time 0.428s | Total Thrust: 8.2567N
# Time 0.428s | Total Thrust: 8.2511N
# Time 0.428s | Total Thrust: 8.2545N
# Time 0.428s | Total Thrust: 8.2525N
# Time 0.428s | Total Thrust: 8.2535N
# Time 0.428s | Total Thrust: 8.2609N
# Time 0.428s | Total Thrust: 8.2592N
# Time 0.428s | Total Thrust: 8.2539N
# Time 0.428s | Total Thrust: 8.2446N
# Time 0.429s | Total Thrust: 8.2378N
# Time 0.429s | Total Thrust: 8.2265N

# %%
import matplotlib.pyplot as plt

time_axis = np.arange(time_steps) * dt

# --- 2. PLOT ---
plt.figure(figsize=(10, 5), dpi=100)

# Plot the instantaneous total thrust
plt.plot(time_axis, thrust_history, 
         color='#1f77b4', 
         label='Total Instantaneous Thrust', 
         lw=1.5)

# Plot the mean thrust line for reference
plt.axhline(y=np.mean(thrust_history), 
            color='red', 
            linestyle='--', 
            label=f'Mean Thrust: {np.mean(thrust_history):.2f} N',
            alpha=0.8)

# Formatting
plt.title('Total Propeller Thrust History', fontsize=14, fontweight='bold')
plt.xlabel('Time (s)', fontsize=12)
plt.ylabel('Thrust (N)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend(loc='upper right')

plt.ylim(0.8*propeller.compute_total_forces()[0], 1.2*propeller.compute_total_forces()[0])

plt.tight_layout()
plt.show()
